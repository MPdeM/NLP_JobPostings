# %% [markdown]
# <a href="https://colab.research.google.com/github/MPdeM/Final_Project/blob/master/machinelearning/nlp_svm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install nltk

# %% [markdown]
# ### **Dependencies**

# %%
# Dependencies
import pandas as pd
import numpy as np
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('stopwords')
from nltk import word_tokenize,sent_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from collections import defaultdict
from nltk.corpus import wordnet as wn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import model_selection, svm
from sklearn.metrics import accuracy_score
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/jobrien1726/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/jobrien1726/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/jobrien1726/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/jobrien1726/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## **Load/Clean Data**

# %%
# Read in csv file
url = "https://job-postings-dataviz.s3.amazonaws.com/fake_jobs_clean.csv"

fake_jobs_df = pd.read_csv(url, sep=",",  encoding = "UTF-8")
fake_jobs_df
# Out:
#        job_id           city state/province country  \
# 0           1       New York             NY      US
# 1           2       Auckland                     NZ
# 2           3          Wever             IA      US
# 3           4     Washington             DC      US
# 4           5     Fort Worth             FL      US
# ...       ...            ...            ...     ...
# 17875   17876        Toronto             ON      CA
# 17876   17877   Philadelphia             PA      US
# 17877   17878        Houston             TX      US
# 17878   17879          Lagos             LA      NG
# 17879   17880     Wellington              N      NZ
#
#                                                    title   department  \
# 0                                       Marketing Intern    Marketing
# 1              Customer Service - Cloud Video Production      Success
# 2                Commissioning Machinery Assistant (CMA)          NaN
# 3                      Account Executive - Washington DC        Sales
# 4                                    Bill Review Manager          NaN
# ...                                                  ...          ...
# 17875                   Account Director - Distribution         Sales
# 17876                                 Payroll Accountant   Accounting
# 17877  Project Cost Control Staff Engineer - Cost Con...          NaN
# 17878                                   Graphic Designer          NaN
# 17879                         Web Application Developers  Engineering
#
#                         industry              function salary_range  \
# 0                            NaN             Marketing          NaN
# 1      Marketing and Advertising      Customer Service          NaN
# 2                            NaN                   NaN          NaN
# 3              Computer Software                 Sales          NaN
# 4         Hospital & Health Care  Health Care Provider          NaN
# ...                          ...                   ...          ...
# 17875          Computer Software                 Sales          NaN
# 17876                   Internet   Accounting/Auditing          NaN
# 17877                        NaN                   NaN          NaN
# 17878             Graphic Design                Design          NaN
# 17879          Computer Software           Engineering          NaN
#
#        salary_provided  ...  \
# 0                    0  ...
# 1                    0  ...
# 2                    0  ...
# 3                    0  ...
# 4                    0  ...
# ...                ...  ...
# 17875                0  ...
# 17876                0  ...
# 17877                0  ...
# 17878                0  ...
# 17879                0  ...
#
#                                             requirements  \
# 0      Experience with content management systems a m...
# 1      What we expect from you:Your key responsibilit...
# 2      Implement pre-commissioning and commissioning ...
# 3      EDUCATION: Bachelor’s or Master’s in GIS, busi...
# 4      QUALIFICATIONS:RN license in the State of Texa...
# ...                                                  ...
# 17875  To ace this role you:Will eat comprehensive St...
# 17876  - B.A. or B.S. in Accounting- Desire to have f...
# 17877  At least 12 years professional experience.Abil...
# 17878  1. Must be fluent in the latest versions of Co...
# 17879  We want to hear from you if:You have an in-dep...
#
#                                                 benefits benefits_provided  \
# 0                                                    NaN                 0
# 1      What you will get from usThrough being part of...                 1
# 2                                                    NaN                 0
# 3      Our culture is anything but corporate—we have ...                 1
# 4                                  Full Benefits Offered                 1
# ...                                                  ...               ...
# 17875  What can you expect from us?We have an open cu...                 1
# 17876  Health &amp; WellnessMedical planPrescription ...                 1
# 17877                                                NaN                 0
# 17878  Competitive salary (compensation will be based...                 1
# 17879                                                NaN                 0
#
#       telecommuting  has_company_logo  has_questions  employment_type  \
# 0                 0                 1              0            Other
# 1                 0                 1              0        Full-time
# 2                 0                 1              0              NaN
# 3                 0                 1              0        Full-time
# 4                 0                 1              1        Full-time
# ...             ...               ...            ...              ...
# 17875             0                 1              1        Full-time
# 17876             0                 1              1        Full-time
# 17877             0                 0              0        Full-time
# 17878             0                 0              1         Contract
# 17879             0                 1              1        Full-time
#
#        required_experience required_education fraudulent
# 0               Internship                NaN          0
# 1           Not Applicable                NaN          0
# 2                      NaN                NaN          0
# 3         Mid-Senior level  Bachelor's Degree          0
# 4         Mid-Senior level  Bachelor's Degree          0
# ...                    ...                ...        ...
# 17875     Mid-Senior level                NaN          0
# 17876     Mid-Senior level  Bachelor's Degree          0
# 17877                  NaN                NaN          0
# 17878       Not Applicable       Professional          0
# 17879     Mid-Senior level                NaN          0
#
# [17880 rows x 22 columns]

# %%
# Take a look at job description and fraudulent cols
df = fake_jobs_df[['description', 'fraudulent']]
df
# Out:
#                                              description  fraudulent
# 0      Food52, a fast-growing, James Beard Award-winn...           0
# 1      Organised - Focused - Vibrant - Awesome!Do you...           0
# 2      Our client, located in Houston, is actively se...           0
# 3      THE COMPANY: ESRI – Environmental Systems Rese...           0
# 4      JOB TITLE: Itemization Review ManagerLOCATION:...           0
# ...                                                  ...         ...
# 17875  Just in case this is the first time you’ve vis...           0
# 17876  The Payroll Accountant will focus primarily on...           0
# 17877  Experienced Project Cost Control Staff Enginee...           0
# 17878  Nemsia Studios is looking for an experienced v...           0
# 17879  Who are we?Vend is an award winning web based ...           0
#
# [17880 rows x 2 columns]

# %%
# Count how many Real vs Fraudulent postings 
from collections import Counter
print(Counter(df['fraudulent'].values))
# Out:
# Counter({0: 17014, 1: 866})

# %%
# Drop duplicate descriptions
df = df.drop_duplicates()
df
# Out:
#                                              description  fraudulent
# 0      Food52, a fast-growing, James Beard Award-winn...           0
# 1      Organised - Focused - Vibrant - Awesome!Do you...           0
# 2      Our client, located in Houston, is actively se...           0
# 3      THE COMPANY: ESRI – Environmental Systems Rese...           0
# 4      JOB TITLE: Itemization Review ManagerLOCATION:...           0
# ...                                                  ...         ...
# 17873  RESPONSIBILITIES:Will facilitate the recruitin...           0
# 17875  Just in case this is the first time you’ve vis...           0
# 17876  The Payroll Accountant will focus primarily on...           0
# 17877  Experienced Project Cost Control Staff Enginee...           0
# 17878  Nemsia Studios is looking for an experienced v...           0
#
# [14803 rows x 2 columns]

# %%
# Count how many Real vs Fraudulent postings 
print(Counter(df['fraudulent'].values))
# Out:
# Counter({0: 14171, 1: 632})

# %%
# Make sure number of real vs fraudulent are more balanced
# Using UNDERsampling for balancing of classification groups
df_fraud= df[df['fraudulent'] == 1] 
df_normal = df[df['fraudulent'] == 0] 

df_normal = df_normal.sample(n=(9*len(df_fraud)), random_state=22)
df = df_normal.append(df_fraud)

df
# Out:
#                                              description  fraudulent
# 13898  Currently hiring per-diem caregivers to work o...           0
# 1688   Μεγαλώνουμε την ομάδα μας,και χρειαζόμαστε ένα...           0
# 13100  PowToon is looking for a team-oriented Marketi...           0
# 5579   Wealth Management Advisor We are continuing ou...           0
# 15961  RECRUITING MILITARY VETERANSLooking to offer o...           0
# ...                                                  ...         ...
# 17827  Student Positions Part-Time and Full-Time.You ...           1
# 17828  LEARN TO EARN AN EXECUTIVE LEVEL INCOMEFULL TR...           1
# 17829  inFullMobile Sp. z o.o. is a mobile software d...           1
# 17830  JOB DESCRIPTIONWe are seeking a full time payr...           1
# 17831  earn $500 to $1000 a week as a mover.  Must ha...           1
#
# [6320 rows x 2 columns]

# %%
# Shuffle the dataframe so fraudulent postings more evenly distributed 
from sklearn.utils import shuffle
df = shuffle(df, random_state=22)
df = df.reset_index(drop=True)
df
# Out:
#                                             description  fraudulent
# 0      The Customer Service Associate will be based ...           0
# 1     Solid seeks to recruit a Digital Account Super...           0
# 2     (We have more than 1500+ Job openings in our w...           0
# 3     Support the Pricing Intelligence initiative by...           0
# 4     Position Summary:  Provide integrity engineeri...           1
# ...                                                 ...         ...
# 6315  Role: Receptionist/Administrator Location: Cam...           0
# 6316  CTO for a tourism start-upWe are just now star...           0
# 6317  Senior FrontEnd Developer for our small and ta...           0
# 6318  We have an immediate opening for a receptionis...           1
# 6319  Qubit: Cutting Edge Big Data EngineeringAt Qub...           0
#
# [6320 rows x 2 columns]

# %%
# Explicitly define data types
df['description'] = df['description'].astype(str)
df['fraudulent'] = df['fraudulent'].astype(int)

# %%
# Datatypes
df.dtypes
# Out:
# description    object
# fraudulent      int64
# dtype: object

# %%
# Count Real vs Fraudulent again to make sure we've achieved the desired result
print(Counter(df['fraudulent'].values))
# Out:
# Counter({0: 5688, 1: 632})

# %% [markdown]
# ## **Data Pre-Processing**

# %%
# Change all the text to lowercase
df['description'] = [x.lower() for x in df['description']]
df['description']
# Out:
# 0        the customer service associate will be based ...
# 1       solid seeks to recruit a digital account super...
# 2       (we have more than 1500+ job openings in our w...
# 3       support the pricing intelligence initiative by...
# 4       position summary:  provide integrity engineeri...
#                               ...
# 6315    role: receptionist/administrator location: cam...
# 6316    cto for a tourism start-upwe are just now star...
# 6317    senior frontend developer for our small and ta...
# 6318    we have an immediate opening for a receptionis...
# 6319    qubit: cutting edge big data engineeringat qub...
# Name: description, Length: 6320, dtype: object

# %%
# Tokenization
df['description']= [word_tokenize(x) for x in df['description']]

# %%
# Remove Stop words and Non-Numeric. Perfom Word Stemming/Lemmenting.
# WordNetLemmatizer requires Pos tags to understand if the word is noun or verb or adjective etc. By default it is set to Noun
tag_map = defaultdict(lambda : wn.NOUN)
tag_map['J'] = wn.ADJ
tag_map['V'] = wn.VERB
tag_map['R'] = wn.ADV

for index,entry in enumerate(df['description']):
    # Declare an Empty List to store the words that follow the rules for this step
    Final_words = []

    # Initialize WordNetLemmatizer()
    word_Lemmatized = WordNetLemmatizer()

    # pos_tag function to provide the 'tag' i.e if the word is Noun(N), Verb(V), ADJ(J) or ADV(R) or something else.
    for word, tag in pos_tag(entry):
        # Below condition is to check for Stop words and consider only alphabets
        if word not in stopwords.words('english') and word.isalpha():
            word_Final = word_Lemmatized.lemmatize(word,tag_map[tag[0]])
            Final_words.append(word_Final)

    # The final processed set of words for each iteration will be stored in 'text_final'
    df.loc[index,'text_final'] = str(Final_words)

df
# Out:
#                                             description  fraudulent  \
# 0     [the, customer, service, associate, will, be, ...           0
# 1     [solid, seeks, to, recruit, a, digital, accoun...           0
# 2     [(, we, have, more, than, 1500+, job, openings...           0
# 3     [support, the, pricing, intelligence, initiati...           0
# 4     [position, summary, :, provide, integrity, eng...           1
# ...                                                 ...         ...
# 6315  [role, :, receptionist/administrator, location...           0
# 6316  [cto, for, a, tourism, start-upwe, are, just, ...           0
# 6317  [senior, frontend, developer, for, our, small,...           0
# 6318  [we, have, an, immediate, opening, for, a, rec...           1
# 6319  [qubit, :, cutting, edge, big, data, engineeri...           0
#
#                                              text_final
# 0     ['customer', 'service', 'associate', 'base', '...
# 1     ['solid', 'seek', 'recruit', 'digital', 'accou...
# 2     ['job', 'opening', 'website', 'relevant', 'job...
# 3     ['support', 'pricing', 'intelligence', 'initia...
# 4     ['position', 'summary', 'provide', 'integrity'...
# ...                                                 ...
# 6315  ['role', 'location', 'camden', 'londoncompany'...
# 6316  ['cto', 'tourism', 'start', 'want', 'join', 'a...
# 6317  ['senior', 'frontend', 'developer', 'small', '...
# 6318  ['immediate', 'opening', 'year', 'experience',...
# 6319  ['qubit', 'cutting', 'edge', 'big', 'data', 'e...
#
# [6320 rows x 3 columns]

# %%
# Reorganize Columns
df = df[['description','text_final','fraudulent']]
df
# Out:
#                                             description  \
# 0     [the, customer, service, associate, will, be, ...
# 1     [solid, seeks, to, recruit, a, digital, accoun...
# 2     [(, we, have, more, than, 1500+, job, openings...
# 3     [support, the, pricing, intelligence, initiati...
# 4     [position, summary, :, provide, integrity, eng...
# ...                                                 ...
# 6315  [role, :, receptionist/administrator, location...
# 6316  [cto, for, a, tourism, start-upwe, are, just, ...
# 6317  [senior, frontend, developer, for, our, small,...
# 6318  [we, have, an, immediate, opening, for, a, rec...
# 6319  [qubit, :, cutting, edge, big, data, engineeri...
#
#                                              text_final  fraudulent
# 0     ['customer', 'service', 'associate', 'base', '...           0
# 1     ['solid', 'seek', 'recruit', 'digital', 'accou...           0
# 2     ['job', 'opening', 'website', 'relevant', 'job...           0
# 3     ['support', 'pricing', 'intelligence', 'initia...           0
# 4     ['position', 'summary', 'provide', 'integrity'...           1
# ...                                                 ...         ...
# 6315  ['role', 'location', 'camden', 'londoncompany'...           0
# 6316  ['cto', 'tourism', 'start', 'want', 'join', 'a...           0
# 6317  ['senior', 'frontend', 'developer', 'small', '...           0
# 6318  ['immediate', 'opening', 'year', 'experience',...           1
# 6319  ['qubit', 'cutting', 'edge', 'big', 'data', 'e...           0
#
# [6320 rows x 3 columns]

# %% [markdown]
# ## **Prepare Training/Testing Data**

# %%
# Prepare Train and Test Data sets
X_train, X_test, Y_train, Y_test = model_selection.train_test_split(df['text_final'],df['fraudulent'],test_size=0.3)

# %% [markdown]
# ## **Word Vectorization w TF-IDF**

# %%
# Word Vectorization using method TF-IDF
Tfidf_vect = TfidfVectorizer(max_features=5000)
Tfidf_vect.fit(df['text_final'])
X_train_Tfidf = Tfidf_vect.transform(X_train)
X_test_Tfidf = Tfidf_vect.transform(X_test)

# View the vocab its learned
print(Tfidf_vect.vocabulary_)
print(X_train_Tfidf)
# Out:
# ----------------------------------------------------------------------
# NameError                            Traceback (most recent call last)
# <ipython-input-1-5d9041c04f33> in <module>
#       1 # Word Vectorization using method TF-IDF
# ----> 2 Tfidf_vect = TfidfVectorizer(max_features=5000)
#       3 Tfidf_vect.fit(df['text_final'])
#       4 X_train_Tfidf = Tfidf_vect.transform(X_train)
#       5 X_test_Tfidf = Tfidf_vect.transform(X_test)
#
# NameError: name 'TfidfVectorizer' is not defined

# %% [markdown]
# # **Train/ Evaluate Model**

# %%
# Classifier Algorithm= Support Vector Machine

# Fit the Classifier w the Training Data
SVM = svm.SVC(C=1.0, kernel='linear', degree=3, gamma='auto')
SVM.fit(X_train_Tfidf, Y_train)

# Use model to get predictions from the Testing data
predictions_SVM = SVM.predict(X_test_Tfidf)

# Use accuracy_score function to get the accuracy
print("SVM Accuracy Score: ", accuracy_score(predictions_SVM, Y_test)*100)
# Out:
# SVM Accuracy Score:  93.24894514767934

# %% [markdown]
# ## **Hypertune Model**

# %%
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV
param_grid = {'C': [1, 5, 10, 100],
              'gamma': [0.001, 0.01, .1, 1],
              'kernel': ['linear','rbf', 'poly', 'sigmoid']}
grid = GridSearchCV(SVM, param_grid, verbose=3)

# %%
# Train the model with GridSearch
grid.fit(X_train_Tfidf, Y_train)
# Out:
# Fitting 5 folds for each of 64 candidates, totalling 320 fits
# [CV] C=1, gamma=0.001, kernel=linear .................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ..... C=1, gamma=0.001, kernel=linear, score=0.924, total=   2.4s
# [CV] C=1, gamma=0.001, kernel=linear .................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    2.4s remaining:    0.0s
# [CV] ..... C=1, gamma=0.001, kernel=linear, score=0.930, total=   2.6s
# [CV] C=1, gamma=0.001, kernel=linear .................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.0s remaining:    0.0s
# [CV] ..... C=1, gamma=0.001, kernel=linear, score=0.932, total=   2.4s
# [CV] C=1, gamma=0.001, kernel=linear .................................
# [CV] ..... C=1, gamma=0.001, kernel=linear, score=0.924, total=   2.4s
# [CV] C=1, gamma=0.001, kernel=linear .................................
# [CV] ..... C=1, gamma=0.001, kernel=linear, score=0.930, total=   2.4s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.902, total=   1.7s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.902, total=   1.7s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.902, total=   1.7s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.901, total=   1.7s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.902, total=   1.7s
# [CV] C=1, gamma=0.001, kernel=poly ...................................
# [CV] ....... C=1, gamma=0.001, kernel=poly, score=0.902, total=   1.5s
# [CV] C=1, gamma=0.001, kernel=poly ...................................
# [CV] ....... C=1, gamma=0.001, kernel=poly, score=0.902, total=   1.5s
# [CV] C=1, gamma=0.001, kernel=poly ...................................
# [CV] ....... C=1, gamma=0.001, kernel=poly, score=0.902, total=   1.5s
# [CV] C=1, gamma=0.001, kernel=poly ...................................
# [CV] ....... C=1, gamma=0.001, kernel=poly, score=0.901, total=   1.5s
# [CV] C=1, gamma=0.001, kernel=poly ...................................
# [CV] ....... C=1, gamma=0.001, kernel=poly, score=0.902, total=   1.5s
# [CV] C=1, gamma=0.001, kernel=sigmoid ................................
# [CV] .... C=1, gamma=0.001, kernel=sigmoid, score=0.902, total=   1.5s
# [CV] C=1, gamma=0.001, kernel=sigmoid ................................
# [CV] .... C=1, gamma=0.001, kernel=sigmoid, score=0.902, total=   1.6s
# [CV] C=1, gamma=0.001, kernel=sigmoid ................................
# [CV] .... C=1, gamma=0.001, kernel=sigmoid, score=0.902, total=   1.6s
# [CV] C=1, gamma=0.001, kernel=sigmoid ................................
# [CV] .... C=1, gamma=0.001, kernel=sigmoid, score=0.901, total=   1.5s
# [CV] C=1, gamma=0.001, kernel=sigmoid ................................
# [CV] .... C=1, gamma=0.001, kernel=sigmoid, score=0.902, total=   1.6s
# [CV] C=1, gamma=0.01, kernel=linear ..................................
# [CV] ...... C=1, gamma=0.01, kernel=linear, score=0.924, total=   2.4s
# [CV] C=1, gamma=0.01, kernel=linear ..................................
# [CV] ...... C=1, gamma=0.01, kernel=linear, score=0.930, total=   2.5s
# [CV] C=1, gamma=0.01, kernel=linear ..................................
# [CV] ...... C=1, gamma=0.01, kernel=linear, score=0.932, total=   2.6s
# [CV] C=1, gamma=0.01, kernel=linear ..................................
# [CV] ...... C=1, gamma=0.01, kernel=linear, score=0.924, total=   2.6s
# [CV] C=1, gamma=0.01, kernel=linear ..................................
# [CV] ...... C=1, gamma=0.01, kernel=linear, score=0.930, total=   2.4s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.902, total=   2.1s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.902, total=   2.2s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.902, total=   2.2s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.901, total=   2.5s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.902, total=   2.2s
# [CV] C=1, gamma=0.01, kernel=poly ....................................
# [CV] ........ C=1, gamma=0.01, kernel=poly, score=0.902, total=   1.5s
# [CV] C=1, gamma=0.01, kernel=poly ....................................
# [CV] ........ C=1, gamma=0.01, kernel=poly, score=0.902, total=   1.5s
# [CV] C=1, gamma=0.01, kernel=poly ....................................
# [CV] ........ C=1, gamma=0.01, kernel=poly, score=0.902, total=   1.5s
# [CV] C=1, gamma=0.01, kernel=poly ....................................
# [CV] ........ C=1, gamma=0.01, kernel=poly, score=0.901, total=   1.5s
# [CV] C=1, gamma=0.01, kernel=poly ....................................
# [CV] ........ C=1, gamma=0.01, kernel=poly, score=0.902, total=   1.5s
# [CV] C=1, gamma=0.01, kernel=sigmoid .................................
# [CV] ..... C=1, gamma=0.01, kernel=sigmoid, score=0.902, total=   2.1s
# [CV] C=1, gamma=0.01, kernel=sigmoid .................................
# [CV] ..... C=1, gamma=0.01, kernel=sigmoid, score=0.902, total=   2.3s
# [CV] C=1, gamma=0.01, kernel=sigmoid .................................
# [CV] ..... C=1, gamma=0.01, kernel=sigmoid, score=0.902, total=   2.2s
# [CV] C=1, gamma=0.01, kernel=sigmoid .................................
# [CV] ..... C=1, gamma=0.01, kernel=sigmoid, score=0.901, total=   2.2s
# [CV] C=1, gamma=0.01, kernel=sigmoid .................................
# [CV] ..... C=1, gamma=0.01, kernel=sigmoid, score=0.902, total=   2.2s
# [CV] C=1, gamma=0.1, kernel=linear ...................................
# [CV] ....... C=1, gamma=0.1, kernel=linear, score=0.924, total=   2.4s
# [CV] C=1, gamma=0.1, kernel=linear ...................................
# [CV] ....... C=1, gamma=0.1, kernel=linear, score=0.930, total=   2.5s
# [CV] C=1, gamma=0.1, kernel=linear ...................................
# [CV] ....... C=1, gamma=0.1, kernel=linear, score=0.932, total=   2.4s
# [CV] C=1, gamma=0.1, kernel=linear ...................................
# [CV] ....... C=1, gamma=0.1, kernel=linear, score=0.924, total=   2.4s
# [CV] C=1, gamma=0.1, kernel=linear ...................................
# [CV] ....... C=1, gamma=0.1, kernel=linear, score=0.930, total=   2.4s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.907, total=   2.3s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.907, total=   2.4s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.904, total=   2.3s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.906, total=   2.4s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.902, total=   2.4s
# [CV] C=1, gamma=0.1, kernel=poly .....................................
# [CV] ......... C=1, gamma=0.1, kernel=poly, score=0.902, total=   1.5s
# [CV] C=1, gamma=0.1, kernel=poly .....................................
# [CV] ......... C=1, gamma=0.1, kernel=poly, score=0.902, total=   1.5s
# [CV] C=1, gamma=0.1, kernel=poly .....................................
# [CV] ......... C=1, gamma=0.1, kernel=poly, score=0.902, total=   1.5s
# [CV] C=1, gamma=0.1, kernel=poly .....................................
# [CV] ......... C=1, gamma=0.1, kernel=poly, score=0.901, total=   1.5s
# [CV] C=1, gamma=0.1, kernel=poly .....................................
# [CV] ......... C=1, gamma=0.1, kernel=poly, score=0.902, total=   1.5s
# [CV] C=1, gamma=0.1, kernel=sigmoid ..................................
# [CV] ...... C=1, gamma=0.1, kernel=sigmoid, score=0.902, total=   2.3s
# [CV] C=1, gamma=0.1, kernel=sigmoid ..................................
# [CV] ...... C=1, gamma=0.1, kernel=sigmoid, score=0.902, total=   2.4s
# [CV] C=1, gamma=0.1, kernel=sigmoid ..................................
# [CV] ...... C=1, gamma=0.1, kernel=sigmoid, score=0.902, total=   2.3s
# [CV] C=1, gamma=0.1, kernel=sigmoid ..................................
# [CV] ...... C=1, gamma=0.1, kernel=sigmoid, score=0.901, total=   2.4s
# [CV] C=1, gamma=0.1, kernel=sigmoid ..................................
# [CV] ...... C=1, gamma=0.1, kernel=sigmoid, score=0.902, total=   2.3s
# [CV] C=1, gamma=1, kernel=linear .....................................
# [CV] ......... C=1, gamma=1, kernel=linear, score=0.924, total=   2.4s
# [CV] C=1, gamma=1, kernel=linear .....................................
# [CV] ......... C=1, gamma=1, kernel=linear, score=0.930, total=   2.5s
# [CV] C=1, gamma=1, kernel=linear .....................................
# [CV] ......... C=1, gamma=1, kernel=linear, score=0.932, total=   2.4s
# [CV] C=1, gamma=1, kernel=linear .....................................
# [CV] ......... C=1, gamma=1, kernel=linear, score=0.924, total=   2.4s
# [CV] C=1, gamma=1, kernel=linear .....................................
# [CV] ......... C=1, gamma=1, kernel=linear, score=0.930, total=   2.4s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.927, total=   4.0s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.925, total=   4.1s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.933, total=   4.1s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.927, total=   4.1s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.928, total=   4.2s
# [CV] C=1, gamma=1, kernel=poly .......................................
# [CV] ........... C=1, gamma=1, kernel=poly, score=0.930, total=   8.0s
# [CV] C=1, gamma=1, kernel=poly .......................................
# [CV] ........... C=1, gamma=1, kernel=poly, score=0.919, total=   7.9s
# [CV] C=1, gamma=1, kernel=poly .......................................
# [CV] ........... C=1, gamma=1, kernel=poly, score=0.929, total=   7.7s
# [CV] C=1, gamma=1, kernel=poly .......................................
# [CV] ........... C=1, gamma=1, kernel=poly, score=0.923, total=   7.7s
# [CV] C=1, gamma=1, kernel=poly .......................................
# [CV] ........... C=1, gamma=1, kernel=poly, score=0.920, total=   7.8s
# [CV] C=1, gamma=1, kernel=sigmoid ....................................
# [CV] ........ C=1, gamma=1, kernel=sigmoid, score=0.920, total=   2.0s
# [CV] C=1, gamma=1, kernel=sigmoid ....................................
# [CV] ........ C=1, gamma=1, kernel=sigmoid, score=0.927, total=   2.2s
# [CV] C=1, gamma=1, kernel=sigmoid ....................................
# [CV] ........ C=1, gamma=1, kernel=sigmoid, score=0.927, total=   2.0s
# [CV] C=1, gamma=1, kernel=sigmoid ....................................
# [CV] ........ C=1, gamma=1, kernel=sigmoid, score=0.923, total=   2.0s
# [CV] C=1, gamma=1, kernel=sigmoid ....................................
# [CV] ........ C=1, gamma=1, kernel=sigmoid, score=0.923, total=   2.0s
# [CV] C=5, gamma=0.001, kernel=linear .................................
# [CV] ..... C=5, gamma=0.001, kernel=linear, score=0.921, total=   2.4s
# [CV] C=5, gamma=0.001, kernel=linear .................................
# [CV] ..... C=5, gamma=0.001, kernel=linear, score=0.930, total=   2.5s
# [CV] C=5, gamma=0.001, kernel=linear .................................
# [CV] ..... C=5, gamma=0.001, kernel=linear, score=0.930, total=   2.5s
# [CV] C=5, gamma=0.001, kernel=linear .................................
# [CV] ..... C=5, gamma=0.001, kernel=linear, score=0.933, total=   2.4s
# [CV] C=5, gamma=0.001, kernel=linear .................................
# [CV] ..... C=5, gamma=0.001, kernel=linear, score=0.923, total=   2.5s
# [CV] C=5, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=5, gamma=0.001, kernel=rbf, score=0.902, total=   2.0s
# [CV] C=5, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=5, gamma=0.001, kernel=rbf, score=0.902, total=   2.1s
# [CV] C=5, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=5, gamma=0.001, kernel=rbf, score=0.902, total=   2.1s
# [CV] C=5, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=5, gamma=0.001, kernel=rbf, score=0.901, total=   2.1s
# [CV] C=5, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=5, gamma=0.001, kernel=rbf, score=0.902, total=   2.1s
# [CV] C=5, gamma=0.001, kernel=poly ...................................
# [CV] ....... C=5, gamma=0.001, kernel=poly, score=0.902, total=   1.5s
# [CV] C=5, gamma=0.001, kernel=poly ...................................
# [CV] ....... C=5, gamma=0.001, kernel=poly, score=0.902, total=   1.5s
# [CV] C=5, gamma=0.001, kernel=poly ...................................
# [CV] ....... C=5, gamma=0.001, kernel=poly, score=0.902, total=   1.5s
# [CV] C=5, gamma=0.001, kernel=poly ...................................
# [CV] ....... C=5, gamma=0.001, kernel=poly, score=0.901, total=   1.5s
# [CV] C=5, gamma=0.001, kernel=poly ...................................
# [CV] ....... C=5, gamma=0.001, kernel=poly, score=0.902, total=   1.5s
# [CV] C=5, gamma=0.001, kernel=sigmoid ................................
# [CV] .... C=5, gamma=0.001, kernel=sigmoid, score=0.902, total=   2.0s
# [CV] C=5, gamma=0.001, kernel=sigmoid ................................
# [CV] .... C=5, gamma=0.001, kernel=sigmoid, score=0.902, total=   2.1s
# [CV] C=5, gamma=0.001, kernel=sigmoid ................................
# [CV] .... C=5, gamma=0.001, kernel=sigmoid, score=0.902, total=   2.0s
# [CV] C=5, gamma=0.001, kernel=sigmoid ................................
# [CV] .... C=5, gamma=0.001, kernel=sigmoid, score=0.901, total=   2.0s
# [CV] C=5, gamma=0.001, kernel=sigmoid ................................
# [CV] .... C=5, gamma=0.001, kernel=sigmoid, score=0.902, total=   2.0s
# [CV] C=5, gamma=0.01, kernel=linear ..................................
# [CV] ...... C=5, gamma=0.01, kernel=linear, score=0.921, total=   2.4s
# [CV] C=5, gamma=0.01, kernel=linear ..................................
# [CV] ...... C=5, gamma=0.01, kernel=linear, score=0.930, total=   2.5s
# [CV] C=5, gamma=0.01, kernel=linear ..................................
# [CV] ...... C=5, gamma=0.01, kernel=linear, score=0.930, total=   2.5s
# [CV] C=5, gamma=0.01, kernel=linear ..................................
# [CV] ...... C=5, gamma=0.01, kernel=linear, score=0.933, total=   2.4s
# [CV] C=5, gamma=0.01, kernel=linear ..................................
# [CV] ...... C=5, gamma=0.01, kernel=linear, score=0.923, total=   2.7s
# [CV] C=5, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=5, gamma=0.01, kernel=rbf, score=0.902, total=   2.2s
# [CV] C=5, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=5, gamma=0.01, kernel=rbf, score=0.902, total=   2.3s
# [CV] C=5, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=5, gamma=0.01, kernel=rbf, score=0.902, total=   2.2s
# [CV] C=5, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=5, gamma=0.01, kernel=rbf, score=0.901, total=   2.3s
# [CV] C=5, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=5, gamma=0.01, kernel=rbf, score=0.902, total=   2.3s
# [CV] C=5, gamma=0.01, kernel=poly ....................................
# [CV] ........ C=5, gamma=0.01, kernel=poly, score=0.902, total=   1.5s
# [CV] C=5, gamma=0.01, kernel=poly ....................................
# [CV] ........ C=5, gamma=0.01, kernel=poly, score=0.902, total=   1.5s
# [CV] C=5, gamma=0.01, kernel=poly ....................................
# [CV] ........ C=5, gamma=0.01, kernel=poly, score=0.902, total=   1.5s
# [CV] C=5, gamma=0.01, kernel=poly ....................................
# [CV] ........ C=5, gamma=0.01, kernel=poly, score=0.901, total=   1.5s
# [CV] C=5, gamma=0.01, kernel=poly ....................................
# [CV] ........ C=5, gamma=0.01, kernel=poly, score=0.902, total=   1.6s
# [CV] C=5, gamma=0.01, kernel=sigmoid .................................
# [CV] ..... C=5, gamma=0.01, kernel=sigmoid, score=0.902, total=   2.2s
# [CV] C=5, gamma=0.01, kernel=sigmoid .................................
# [CV] ..... C=5, gamma=0.01, kernel=sigmoid, score=0.902, total=   2.4s
# [CV] C=5, gamma=0.01, kernel=sigmoid .................................
# [CV] ..... C=5, gamma=0.01, kernel=sigmoid, score=0.902, total=   2.3s
# [CV] C=5, gamma=0.01, kernel=sigmoid .................................
# [CV] ..... C=5, gamma=0.01, kernel=sigmoid, score=0.901, total=   2.3s
# [CV] C=5, gamma=0.01, kernel=sigmoid .................................
# [CV] ..... C=5, gamma=0.01, kernel=sigmoid, score=0.902, total=   2.3s
# [CV] C=5, gamma=0.1, kernel=linear ...................................
# [CV] ....... C=5, gamma=0.1, kernel=linear, score=0.921, total=   2.4s
# [CV] C=5, gamma=0.1, kernel=linear ...................................
# [CV] ....... C=5, gamma=0.1, kernel=linear, score=0.930, total=   2.5s
# [CV] C=5, gamma=0.1, kernel=linear ...................................
# [CV] ....... C=5, gamma=0.1, kernel=linear, score=0.930, total=   2.5s
# [CV] C=5, gamma=0.1, kernel=linear ...................................
# [CV] ....... C=5, gamma=0.1, kernel=linear, score=0.933, total=   2.5s
# [CV] C=5, gamma=0.1, kernel=linear ...................................
# [CV] ....... C=5, gamma=0.1, kernel=linear, score=0.923, total=   2.5s
# [CV] C=5, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=5, gamma=0.1, kernel=rbf, score=0.924, total=   2.5s
# [CV] C=5, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=5, gamma=0.1, kernel=rbf, score=0.930, total=   2.6s
# [CV] C=5, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=5, gamma=0.1, kernel=rbf, score=0.931, total=   2.4s
# [CV] C=5, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=5, gamma=0.1, kernel=rbf, score=0.924, total=   2.5s
# [CV] C=5, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=5, gamma=0.1, kernel=rbf, score=0.925, total=   2.6s
# [CV] C=5, gamma=0.1, kernel=poly .....................................
# [CV] ......... C=5, gamma=0.1, kernel=poly, score=0.902, total=   5.2s
# [CV] C=5, gamma=0.1, kernel=poly .....................................
# [CV] ......... C=5, gamma=0.1, kernel=poly, score=0.902, total=   5.0s
# [CV] C=5, gamma=0.1, kernel=poly .....................................
# [CV] ......... C=5, gamma=0.1, kernel=poly, score=0.902, total=   5.1s
# [CV] C=5, gamma=0.1, kernel=poly .....................................
# [CV] ......... C=5, gamma=0.1, kernel=poly, score=0.901, total=   5.1s
# [CV] C=5, gamma=0.1, kernel=poly .....................................
# [CV] ......... C=5, gamma=0.1, kernel=poly, score=0.902, total=   5.1s
# [CV] C=5, gamma=0.1, kernel=sigmoid ..................................
# [CV] ...... C=5, gamma=0.1, kernel=sigmoid, score=0.919, total=   2.4s
# [CV] C=5, gamma=0.1, kernel=sigmoid ..................................
# [CV] ...... C=5, gamma=0.1, kernel=sigmoid, score=0.919, total=   2.5s
# [CV] C=5, gamma=0.1, kernel=sigmoid ..................................
# [CV] ...... C=5, gamma=0.1, kernel=sigmoid, score=0.921, total=   2.4s
# [CV] C=5, gamma=0.1, kernel=sigmoid ..................................
# [CV] ...... C=5, gamma=0.1, kernel=sigmoid, score=0.916, total=   2.4s
# [CV] C=5, gamma=0.1, kernel=sigmoid ..................................
# [CV] ...... C=5, gamma=0.1, kernel=sigmoid, score=0.921, total=   2.4s
# [CV] C=5, gamma=1, kernel=linear .....................................
# [CV] ......... C=5, gamma=1, kernel=linear, score=0.921, total=   2.4s
# [CV] C=5, gamma=1, kernel=linear .....................................
# [CV] ......... C=5, gamma=1, kernel=linear, score=0.930, total=   2.5s
# [CV] C=5, gamma=1, kernel=linear .....................................
# [CV] ......... C=5, gamma=1, kernel=linear, score=0.930, total=   2.5s
# [CV] C=5, gamma=1, kernel=linear .....................................
# [CV] ......... C=5, gamma=1, kernel=linear, score=0.933, total=   2.5s
# [CV] C=5, gamma=1, kernel=linear .....................................
# [CV] ......... C=5, gamma=1, kernel=linear, score=0.923, total=   2.5s
# [CV] C=5, gamma=1, kernel=rbf ........................................
# [CV] ............ C=5, gamma=1, kernel=rbf, score=0.934, total=   5.8s
# [CV] C=5, gamma=1, kernel=rbf ........................................
# [CV] ............ C=5, gamma=1, kernel=rbf, score=0.938, total=   5.8s
# [CV] C=5, gamma=1, kernel=rbf ........................................
# [CV] ............ C=5, gamma=1, kernel=rbf, score=0.940, total=   5.8s
# [CV] C=5, gamma=1, kernel=rbf ........................................
# [CV] ............ C=5, gamma=1, kernel=rbf, score=0.940, total=   5.8s
# [CV] C=5, gamma=1, kernel=rbf ........................................
# [CV] ............ C=5, gamma=1, kernel=rbf, score=0.934, total=   5.8s
# [CV] C=5, gamma=1, kernel=poly .......................................
# [CV] ........... C=5, gamma=1, kernel=poly, score=0.931, total=   7.9s
# [CV] C=5, gamma=1, kernel=poly .......................................
# [CV] ........... C=5, gamma=1, kernel=poly, score=0.929, total=   7.9s
# [CV] C=5, gamma=1, kernel=poly .......................................
# [CV] ........... C=5, gamma=1, kernel=poly, score=0.934, total=   8.0s
# [CV] C=5, gamma=1, kernel=poly .......................................
# [CV] ........... C=5, gamma=1, kernel=poly, score=0.933, total=   7.9s
# [CV] C=5, gamma=1, kernel=poly .......................................
# [CV] ........... C=5, gamma=1, kernel=poly, score=0.926, total=   8.1s
# [CV] C=5, gamma=1, kernel=sigmoid ....................................
# [CV] ........ C=5, gamma=1, kernel=sigmoid, score=0.911, total=   1.9s
# [CV] C=5, gamma=1, kernel=sigmoid ....................................
# [CV] ........ C=5, gamma=1, kernel=sigmoid, score=0.920, total=   2.1s
# [CV] C=5, gamma=1, kernel=sigmoid ....................................
# [CV] ........ C=5, gamma=1, kernel=sigmoid, score=0.912, total=   2.0s
# [CV] C=5, gamma=1, kernel=sigmoid ....................................
# [CV] ........ C=5, gamma=1, kernel=sigmoid, score=0.921, total=   2.0s
# [CV] C=5, gamma=1, kernel=sigmoid ....................................
# [CV] ........ C=5, gamma=1, kernel=sigmoid, score=0.911, total=   2.0s
# [CV] C=10, gamma=0.001, kernel=linear ................................
# [CV] .... C=10, gamma=0.001, kernel=linear, score=0.914, total=   2.4s
# [CV] C=10, gamma=0.001, kernel=linear ................................
# [CV] .... C=10, gamma=0.001, kernel=linear, score=0.927, total=   2.5s
# [CV] C=10, gamma=0.001, kernel=linear ................................
# [CV] .... C=10, gamma=0.001, kernel=linear, score=0.922, total=   2.7s
# [CV] C=10, gamma=0.001, kernel=linear ................................
# [CV] .... C=10, gamma=0.001, kernel=linear, score=0.930, total=   2.6s
# [CV] C=10, gamma=0.001, kernel=linear ................................
# [CV] .... C=10, gamma=0.001, kernel=linear, score=0.924, total=   2.7s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.902, total=   2.3s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.902, total=   2.3s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.902, total=   2.3s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.901, total=   2.2s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.902, total=   2.3s
# [CV] C=10, gamma=0.001, kernel=poly ..................................
# [CV] ...... C=10, gamma=0.001, kernel=poly, score=0.902, total=   1.6s
# [CV] C=10, gamma=0.001, kernel=poly ..................................
# [CV] ...... C=10, gamma=0.001, kernel=poly, score=0.902, total=   1.7s
# [CV] C=10, gamma=0.001, kernel=poly ..................................
# [CV] ...... C=10, gamma=0.001, kernel=poly, score=0.902, total=   1.5s
# [CV] C=10, gamma=0.001, kernel=poly ..................................
# [CV] ...... C=10, gamma=0.001, kernel=poly, score=0.901, total=   1.5s
# [CV] C=10, gamma=0.001, kernel=poly ..................................
# [CV] ...... C=10, gamma=0.001, kernel=poly, score=0.902, total=   1.5s
# [CV] C=10, gamma=0.001, kernel=sigmoid ...............................
# [CV] ... C=10, gamma=0.001, kernel=sigmoid, score=0.902, total=   2.1s
# [CV] C=10, gamma=0.001, kernel=sigmoid ...............................
# [CV] ... C=10, gamma=0.001, kernel=sigmoid, score=0.902, total=   2.5s
# [CV] C=10, gamma=0.001, kernel=sigmoid ...............................
# [CV] ... C=10, gamma=0.001, kernel=sigmoid, score=0.902, total=   2.4s
# [CV] C=10, gamma=0.001, kernel=sigmoid ...............................
# [CV] ... C=10, gamma=0.001, kernel=sigmoid, score=0.901, total=   2.3s
# [CV] C=10, gamma=0.001, kernel=sigmoid ...............................
# [CV] ... C=10, gamma=0.001, kernel=sigmoid, score=0.902, total=   2.2s
# [CV] C=10, gamma=0.01, kernel=linear .................................
# [CV] ..... C=10, gamma=0.01, kernel=linear, score=0.914, total=   2.5s
# [CV] C=10, gamma=0.01, kernel=linear .................................
# [CV] ..... C=10, gamma=0.01, kernel=linear, score=0.927, total=   2.5s
# [CV] C=10, gamma=0.01, kernel=linear .................................
# [CV] ..... C=10, gamma=0.01, kernel=linear, score=0.922, total=   2.7s
# [CV] C=10, gamma=0.01, kernel=linear .................................
# [CV] ..... C=10, gamma=0.01, kernel=linear, score=0.930, total=   2.7s
# [CV] C=10, gamma=0.01, kernel=linear .................................
# [CV] ..... C=10, gamma=0.01, kernel=linear, score=0.924, total=   2.5s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.907, total=   2.2s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.908, total=   2.3s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.905, total=   2.3s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.907, total=   2.3s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.902, total=   2.2s
# [CV] C=10, gamma=0.01, kernel=poly ...................................
# [CV] ....... C=10, gamma=0.01, kernel=poly, score=0.902, total=   1.5s
# [CV] C=10, gamma=0.01, kernel=poly ...................................
# [CV] ....... C=10, gamma=0.01, kernel=poly, score=0.902, total=   1.5s
# [CV] C=10, gamma=0.01, kernel=poly ...................................
# [CV] ....... C=10, gamma=0.01, kernel=poly, score=0.902, total=   1.5s
# [CV] C=10, gamma=0.01, kernel=poly ...................................
# [CV] ....... C=10, gamma=0.01, kernel=poly, score=0.901, total=   1.5s
# [CV] C=10, gamma=0.01, kernel=poly ...................................
# [CV] ....... C=10, gamma=0.01, kernel=poly, score=0.902, total=   1.5s
# [CV] C=10, gamma=0.01, kernel=sigmoid ................................
# [CV] .... C=10, gamma=0.01, kernel=sigmoid, score=0.902, total=   2.3s
# [CV] C=10, gamma=0.01, kernel=sigmoid ................................
# [CV] .... C=10, gamma=0.01, kernel=sigmoid, score=0.902, total=   2.4s
# [CV] C=10, gamma=0.01, kernel=sigmoid ................................
# [CV] .... C=10, gamma=0.01, kernel=sigmoid, score=0.902, total=   2.3s
# [CV] C=10, gamma=0.01, kernel=sigmoid ................................
# [CV] .... C=10, gamma=0.01, kernel=sigmoid, score=0.901, total=   2.4s
# [CV] C=10, gamma=0.01, kernel=sigmoid ................................
# [CV] .... C=10, gamma=0.01, kernel=sigmoid, score=0.902, total=   2.3s
# [CV] C=10, gamma=0.1, kernel=linear ..................................
# [CV] ...... C=10, gamma=0.1, kernel=linear, score=0.914, total=   2.4s
# [CV] C=10, gamma=0.1, kernel=linear ..................................
# [CV] ...... C=10, gamma=0.1, kernel=linear, score=0.927, total=   2.5s
# [CV] C=10, gamma=0.1, kernel=linear ..................................
# [CV] ...... C=10, gamma=0.1, kernel=linear, score=0.922, total=   2.5s
# [CV] C=10, gamma=0.1, kernel=linear ..................................
# [CV] ...... C=10, gamma=0.1, kernel=linear, score=0.930, total=   2.4s
# [CV] C=10, gamma=0.1, kernel=linear ..................................
# [CV] ...... C=10, gamma=0.1, kernel=linear, score=0.924, total=   2.5s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.928, total=   2.5s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.937, total=   2.6s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.939, total=   2.6s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.938, total=   2.5s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.933, total=   2.5s
# [CV] C=10, gamma=0.1, kernel=poly ....................................
# [CV] ........ C=10, gamma=0.1, kernel=poly, score=0.902, total=   6.3s
# [CV] C=10, gamma=0.1, kernel=poly ....................................
# [CV] ........ C=10, gamma=0.1, kernel=poly, score=0.902, total=   6.3s
# [CV] C=10, gamma=0.1, kernel=poly ....................................
# [CV] ........ C=10, gamma=0.1, kernel=poly, score=0.902, total=   6.3s
# [CV] C=10, gamma=0.1, kernel=poly ....................................
# [CV] ........ C=10, gamma=0.1, kernel=poly, score=0.901, total=   6.3s
# [CV] C=10, gamma=0.1, kernel=poly ....................................
# [CV] ........ C=10, gamma=0.1, kernel=poly, score=0.902, total=   6.3s
# [CV] C=10, gamma=0.1, kernel=sigmoid .................................
# [CV] ..... C=10, gamma=0.1, kernel=sigmoid, score=0.924, total=   2.3s
# [CV] C=10, gamma=0.1, kernel=sigmoid .................................
# [CV] ..... C=10, gamma=0.1, kernel=sigmoid, score=0.930, total=   2.5s
# [CV] C=10, gamma=0.1, kernel=sigmoid .................................
# [CV] ..... C=10, gamma=0.1, kernel=sigmoid, score=0.932, total=   2.4s
# [CV] C=10, gamma=0.1, kernel=sigmoid .................................
# [CV] ..... C=10, gamma=0.1, kernel=sigmoid, score=0.924, total=   2.4s
# [CV] C=10, gamma=0.1, kernel=sigmoid .................................
# [CV] ..... C=10, gamma=0.1, kernel=sigmoid, score=0.930, total=   2.4s
# [CV] C=10, gamma=1, kernel=linear ....................................
# [CV] ........ C=10, gamma=1, kernel=linear, score=0.914, total=   2.4s
# [CV] C=10, gamma=1, kernel=linear ....................................
# [CV] ........ C=10, gamma=1, kernel=linear, score=0.927, total=   2.4s
# [CV] C=10, gamma=1, kernel=linear ....................................
# [CV] ........ C=10, gamma=1, kernel=linear, score=0.922, total=   2.4s
# [CV] C=10, gamma=1, kernel=linear ....................................
# [CV] ........ C=10, gamma=1, kernel=linear, score=0.930, total=   2.4s
# [CV] C=10, gamma=1, kernel=linear ....................................
# [CV] ........ C=10, gamma=1, kernel=linear, score=0.924, total=   2.5s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.934, total=   5.8s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.940, total=   5.8s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.940, total=   5.8s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.940, total=   5.8s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.934, total=   5.8s
# [CV] C=10, gamma=1, kernel=poly ......................................
# [CV] .......... C=10, gamma=1, kernel=poly, score=0.931, total=   7.9s
# [CV] C=10, gamma=1, kernel=poly ......................................
# [CV] .......... C=10, gamma=1, kernel=poly, score=0.929, total=   8.0s
# [CV] C=10, gamma=1, kernel=poly ......................................
# [CV] .......... C=10, gamma=1, kernel=poly, score=0.934, total=   8.2s
# [CV] C=10, gamma=1, kernel=poly ......................................
# [CV] .......... C=10, gamma=1, kernel=poly, score=0.933, total=   8.1s
# [CV] C=10, gamma=1, kernel=poly ......................................
# [CV] .......... C=10, gamma=1, kernel=poly, score=0.926, total=   7.9s
# [CV] C=10, gamma=1, kernel=sigmoid ...................................
# [CV] ....... C=10, gamma=1, kernel=sigmoid, score=0.889, total=   1.9s
# [CV] C=10, gamma=1, kernel=sigmoid ...................................
# [CV] ....... C=10, gamma=1, kernel=sigmoid, score=0.903, total=   2.0s
# [CV] C=10, gamma=1, kernel=sigmoid ...................................
# [CV] ....... C=10, gamma=1, kernel=sigmoid, score=0.899, total=   1.9s
# [CV] C=10, gamma=1, kernel=sigmoid ...................................
# [CV] ....... C=10, gamma=1, kernel=sigmoid, score=0.915, total=   2.0s
# [CV] C=10, gamma=1, kernel=sigmoid ...................................
# [CV] ....... C=10, gamma=1, kernel=sigmoid, score=0.899, total=   1.9s
# [CV] C=100, gamma=0.001, kernel=linear ...............................
# [CV] ... C=100, gamma=0.001, kernel=linear, score=0.911, total=   2.4s
# [CV] C=100, gamma=0.001, kernel=linear ...............................
# [CV] ... C=100, gamma=0.001, kernel=linear, score=0.911, total=   2.4s
# [CV] C=100, gamma=0.001, kernel=linear ...............................
# [CV] ... C=100, gamma=0.001, kernel=linear, score=0.916, total=   2.4s
# [CV] C=100, gamma=0.001, kernel=linear ...............................
# [CV] ... C=100, gamma=0.001, kernel=linear, score=0.908, total=   2.4s
# [CV] C=100, gamma=0.001, kernel=linear ...............................
# [CV] ... C=100, gamma=0.001, kernel=linear, score=0.912, total=   2.4s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.908, total=   2.3s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.908, total=   2.3s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.908, total=   2.2s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.907, total=   2.3s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.902, total=   2.2s
# [CV] C=100, gamma=0.001, kernel=poly .................................
# [CV] ..... C=100, gamma=0.001, kernel=poly, score=0.902, total=   1.5s
# [CV] C=100, gamma=0.001, kernel=poly .................................
# [CV] ..... C=100, gamma=0.001, kernel=poly, score=0.902, total=   1.6s
# [CV] C=100, gamma=0.001, kernel=poly .................................
# [CV] ..... C=100, gamma=0.001, kernel=poly, score=0.902, total=   1.5s
# [CV] C=100, gamma=0.001, kernel=poly .................................
# [CV] ..... C=100, gamma=0.001, kernel=poly, score=0.901, total=   1.5s
# [CV] C=100, gamma=0.001, kernel=poly .................................
# [CV] ..... C=100, gamma=0.001, kernel=poly, score=0.902, total=   1.5s
# [CV] C=100, gamma=0.001, kernel=sigmoid ..............................
# [CV] .. C=100, gamma=0.001, kernel=sigmoid, score=0.902, total=   2.3s
# [CV] C=100, gamma=0.001, kernel=sigmoid ..............................
# [CV] .. C=100, gamma=0.001, kernel=sigmoid, score=0.902, total=   2.4s
# [CV] C=100, gamma=0.001, kernel=sigmoid ..............................
# [CV] .. C=100, gamma=0.001, kernel=sigmoid, score=0.902, total=   2.3s
# [CV] C=100, gamma=0.001, kernel=sigmoid ..............................
# [CV] .. C=100, gamma=0.001, kernel=sigmoid, score=0.901, total=   2.4s
# [CV] C=100, gamma=0.001, kernel=sigmoid ..............................
# [CV] .. C=100, gamma=0.001, kernel=sigmoid, score=0.902, total=   2.4s
# [CV] C=100, gamma=0.01, kernel=linear ................................
# [CV] .... C=100, gamma=0.01, kernel=linear, score=0.911, total=   2.5s
# [CV] C=100, gamma=0.01, kernel=linear ................................
# [CV] .... C=100, gamma=0.01, kernel=linear, score=0.911, total=   2.4s
# [CV] C=100, gamma=0.01, kernel=linear ................................
# [CV] .... C=100, gamma=0.01, kernel=linear, score=0.916, total=   2.4s
# [CV] C=100, gamma=0.01, kernel=linear ................................
# [CV] .... C=100, gamma=0.01, kernel=linear, score=0.908, total=   2.6s
# [CV] C=100, gamma=0.01, kernel=linear ................................
# [CV] .... C=100, gamma=0.01, kernel=linear, score=0.912, total=   2.3s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.928, total=   2.3s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.934, total=   2.5s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.933, total=   2.4s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.938, total=   2.4s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.932, total=   2.3s
# [CV] C=100, gamma=0.01, kernel=poly ..................................
# [CV] ...... C=100, gamma=0.01, kernel=poly, score=0.902, total=   1.5s
# [CV] C=100, gamma=0.01, kernel=poly ..................................
# [CV] ...... C=100, gamma=0.01, kernel=poly, score=0.902, total=   1.5s
# [CV] C=100, gamma=0.01, kernel=poly ..................................
# [CV] ...... C=100, gamma=0.01, kernel=poly, score=0.902, total=   1.5s
# [CV] C=100, gamma=0.01, kernel=poly ..................................
# [CV] ...... C=100, gamma=0.01, kernel=poly, score=0.901, total=   1.5s
# [CV] C=100, gamma=0.01, kernel=poly ..................................
# [CV] ...... C=100, gamma=0.01, kernel=poly, score=0.902, total=   1.5s
# [CV] C=100, gamma=0.01, kernel=sigmoid ...............................
# [CV] ... C=100, gamma=0.01, kernel=sigmoid, score=0.924, total=   2.4s
# [CV] C=100, gamma=0.01, kernel=sigmoid ...............................
# [CV] ... C=100, gamma=0.01, kernel=sigmoid, score=0.930, total=   2.6s
# [CV] C=100, gamma=0.01, kernel=sigmoid ...............................
# [CV] ... C=100, gamma=0.01, kernel=sigmoid, score=0.932, total=   2.4s
# [CV] C=100, gamma=0.01, kernel=sigmoid ...............................
# [CV] ... C=100, gamma=0.01, kernel=sigmoid, score=0.924, total=   2.4s
# [CV] C=100, gamma=0.01, kernel=sigmoid ...............................
# [CV] ... C=100, gamma=0.01, kernel=sigmoid, score=0.930, total=   2.4s
# [CV] C=100, gamma=0.1, kernel=linear .................................
# [CV] ..... C=100, gamma=0.1, kernel=linear, score=0.911, total=   2.5s
# [CV] C=100, gamma=0.1, kernel=linear .................................
# [CV] ..... C=100, gamma=0.1, kernel=linear, score=0.911, total=   2.6s
# [CV] C=100, gamma=0.1, kernel=linear .................................
# [CV] ..... C=100, gamma=0.1, kernel=linear, score=0.916, total=   2.4s
# [CV] C=100, gamma=0.1, kernel=linear .................................
# [CV] ..... C=100, gamma=0.1, kernel=linear, score=0.908, total=   2.4s
# [CV] C=100, gamma=0.1, kernel=linear .................................
# [CV] ..... C=100, gamma=0.1, kernel=linear, score=0.912, total=   2.3s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.922, total=   2.5s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.936, total=   2.6s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.930, total=   2.6s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.938, total=   2.6s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.929, total=   2.6s
# [CV] C=100, gamma=0.1, kernel=poly ...................................
# [CV] ....... C=100, gamma=0.1, kernel=poly, score=0.902, total=   7.6s
# [CV] C=100, gamma=0.1, kernel=poly ...................................
# [CV] ....... C=100, gamma=0.1, kernel=poly, score=0.902, total=   7.5s
# [CV] C=100, gamma=0.1, kernel=poly ...................................
# [CV] ....... C=100, gamma=0.1, kernel=poly, score=0.902, total=   7.2s
# [CV] C=100, gamma=0.1, kernel=poly ...................................
# [CV] ....... C=100, gamma=0.1, kernel=poly, score=0.901, total=   7.3s
# [CV] C=100, gamma=0.1, kernel=poly ...................................
# [CV] ....... C=100, gamma=0.1, kernel=poly, score=0.902, total=   7.4s
# [CV] C=100, gamma=0.1, kernel=sigmoid ................................
# [CV] .... C=100, gamma=0.1, kernel=sigmoid, score=0.914, total=   2.4s
# [CV] C=100, gamma=0.1, kernel=sigmoid ................................
# [CV] .... C=100, gamma=0.1, kernel=sigmoid, score=0.927, total=   2.5s
# [CV] C=100, gamma=0.1, kernel=sigmoid ................................
# [CV] .... C=100, gamma=0.1, kernel=sigmoid, score=0.922, total=   2.5s
# [CV] C=100, gamma=0.1, kernel=sigmoid ................................
# [CV] .... C=100, gamma=0.1, kernel=sigmoid, score=0.931, total=   2.5s
# [CV] C=100, gamma=0.1, kernel=sigmoid ................................
# [CV] .... C=100, gamma=0.1, kernel=sigmoid, score=0.924, total=   2.4s
# [CV] C=100, gamma=1, kernel=linear ...................................
# [CV] ....... C=100, gamma=1, kernel=linear, score=0.911, total=   2.4s
# [CV] C=100, gamma=1, kernel=linear ...................................
# [CV] ....... C=100, gamma=1, kernel=linear, score=0.911, total=   2.4s
# [CV] C=100, gamma=1, kernel=linear ...................................
# [CV] ....... C=100, gamma=1, kernel=linear, score=0.916, total=   2.4s
# [CV] C=100, gamma=1, kernel=linear ...................................
# [CV] ....... C=100, gamma=1, kernel=linear, score=0.908, total=   2.5s
# [CV] C=100, gamma=1, kernel=linear ...................................
# [CV] ....... C=100, gamma=1, kernel=linear, score=0.912, total=   2.3s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.934, total=   5.7s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.939, total=   6.3s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.939, total=   5.7s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.939, total=   5.8s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.936, total=   5.8s
# [CV] C=100, gamma=1, kernel=poly .....................................
# [CV] ......... C=100, gamma=1, kernel=poly, score=0.931, total=   8.2s
# [CV] C=100, gamma=1, kernel=poly .....................................
# [CV] ......... C=100, gamma=1, kernel=poly, score=0.931, total=   8.7s
# [CV] C=100, gamma=1, kernel=poly .....................................
# [CV] ......... C=100, gamma=1, kernel=poly, score=0.934, total=   8.8s
# [CV] C=100, gamma=1, kernel=poly .....................................
# [CV] ......... C=100, gamma=1, kernel=poly, score=0.933, total=   8.8s
# [CV] C=100, gamma=1, kernel=poly .....................................
# [CV] ......... C=100, gamma=1, kernel=poly, score=0.928, total=   8.9s
# [CV] C=100, gamma=1, kernel=sigmoid ..................................
# [CV] ...... C=100, gamma=1, kernel=sigmoid, score=0.862, total=   2.3s
# [CV] C=100, gamma=1, kernel=sigmoid ..................................
# [CV] ...... C=100, gamma=1, kernel=sigmoid, score=0.845, total=   2.4s
# [CV] C=100, gamma=1, kernel=sigmoid ..................................
# [CV] ...... C=100, gamma=1, kernel=sigmoid, score=0.878, total=   2.2s
# [CV] C=100, gamma=1, kernel=sigmoid ..................................
# [CV] ...... C=100, gamma=1, kernel=sigmoid, score=0.877, total=   2.3s
# [CV] C=100, gamma=1, kernel=sigmoid ..................................
# [CV] ...... C=100, gamma=1, kernel=sigmoid, score=0.888, total=   2.7s
# [Parallel(n_jobs=1)]: Done 320 out of 320 | elapsed: 15.7min finished
# GridSearchCV(cv=None, error_score=nan,
#              estimator=SVC(C=1.0, break_ties=False, cache_size=200,
#                            class_weight=None, coef0=0.0,
#                            decision_function_shape='ovr', degree=3,
#                            gamma='auto', kernel='linear', max_iter=-1,
#                            probability=False, random_state=None, shrinking=True,
#                            tol=0.001, verbose=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'C': [1, 5, 10, 100], 'gamma': [0.001, 0.01, 0.1, 1],
#                          'kernel': ['linear', 'rbf', 'poly', 'sigmoid']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'C': 10, 'gamma': 1, 'kernel': 'rbf'}
# 0.9378382800316999

# %%
# Train the hypertuned model
SVM2 = svm.SVC(kernel='rbf', C= 10, gamma= 1)
SVM2.fit(X_train_Tfidf, Y_train)
# Out:
# SVC(C=10, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=1, kernel='rbf', max_iter=-1,
#     probability=False, random_state=None, shrinking=True, tol=0.001,
#     verbose=False)

# %%
# Hypertuned Model Accuracy
print('SVM2 Acc Score: %.3f' % SVM2.score(X_test_Tfidf, Y_test))
# Out:
# SVM2 Acc Score: 0.942

# %%
from sklearn.metrics import classification_report
predictions = SVM2.predict(X_test_Tfidf)
print("SVM2 Classification Report: \n" + classification_report(Y_test, predictions, target_names=['real','fake']))
# Out:
# SVM2 Classification Report:
#               precision    recall  f1-score   support
#
#         real       0.94      1.00      0.97      1700
#         fake       0.97      0.45      0.62       196
#
#     accuracy                           0.94      1896
#    macro avg       0.95      0.73      0.79      1896
# weighted avg       0.94      0.94      0.93      1896

# %% [markdown]
# ## **Save Model**
