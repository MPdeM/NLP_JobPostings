# %% [markdown]
# <a href="https://colab.research.google.com/github/MPdeM/Final_Project/blob/master/machinelearning/nlp_svm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Dependencies**

# %%
# Dependencies
import pandas as pd
import numpy as np
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('stopwords')
from nltk import word_tokenize,sent_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from collections import defaultdict
from nltk.corpus import wordnet as wn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import model_selection, svm
from sklearn.metrics import accuracy_score
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## **Load/Clean Data**

# %%
# Read in csv file
url = "https://job-postings-dataviz.s3.amazonaws.com/fake_jobs_clean.csv"

fake_jobs_df = pd.read_csv(url, sep=",",  encoding = "UTF-8")
fake_jobs_df
# Out:
#        job_id           city  ... required_education fraudulent
# 0           1       New York  ...                NaN          0
# 1           2       Auckland  ...                NaN          0
# 2           3          Wever  ...                NaN          0
# 3           4     Washington  ...  Bachelor's Degree          0
# 4           5     Fort Worth  ...  Bachelor's Degree          0
# ...       ...            ...  ...                ...        ...
# 17875   17876        Toronto  ...                NaN          0
# 17876   17877   Philadelphia  ...  Bachelor's Degree          0
# 17877   17878        Houston  ...                NaN          0
# 17878   17879          Lagos  ...       Professional          0
# 17879   17880     Wellington  ...                NaN          0
#
# [17880 rows x 22 columns]

# %%
# Take a look at job description and fraudulent cols
df = fake_jobs_df[['description', 'fraudulent']]
df
# Out:
#                                              description  fraudulent
# 0      Food52, a fast-growing, James Beard Award-winn...           0
# 1      Organised - Focused - Vibrant - Awesome!Do you...           0
# 2      Our client, located in Houston, is actively se...           0
# 3      THE COMPANY: ESRI – Environmental Systems Rese...           0
# 4      JOB TITLE: Itemization Review ManagerLOCATION:...           0
# ...                                                  ...         ...
# 17875  Just in case this is the first time you’ve vis...           0
# 17876  The Payroll Accountant will focus primarily on...           0
# 17877  Experienced Project Cost Control Staff Enginee...           0
# 17878  Nemsia Studios is looking for an experienced v...           0
# 17879  Who are we?Vend is an award winning web based ...           0
#
# [17880 rows x 2 columns]

# %%
# Count how many Real vs Fraudulent postings 
from collections import Counter
print(Counter(df['fraudulent'].values))
# Out:
# Counter({0: 17014, 1: 866})

# %%
# Drop duplicate descriptions
df = df.drop_duplicates()
df
# Out:
#                                              description  fraudulent
# 0      Food52, a fast-growing, James Beard Award-winn...           0
# 1      Organised - Focused - Vibrant - Awesome!Do you...           0
# 2      Our client, located in Houston, is actively se...           0
# 3      THE COMPANY: ESRI – Environmental Systems Rese...           0
# 4      JOB TITLE: Itemization Review ManagerLOCATION:...           0
# ...                                                  ...         ...
# 17873  RESPONSIBILITIES:Will facilitate the recruitin...           0
# 17875  Just in case this is the first time you’ve vis...           0
# 17876  The Payroll Accountant will focus primarily on...           0
# 17877  Experienced Project Cost Control Staff Enginee...           0
# 17878  Nemsia Studios is looking for an experienced v...           0
#
# [14803 rows x 2 columns]

# %%
# Count how many Real vs Fraudulent postings 
print(Counter(df['fraudulent'].values))
# Out:
# Counter({0: 14171, 1: 632})

# %%
# Make sure number of real vs fraudulent are more balanced
# Using UNDERsampling for balancing of classification groups
df_fraud= df[df['fraudulent'] == 1] 
df_normal = df[df['fraudulent'] == 0] 

df_normal = df_normal.sample(n=(7*len(df_fraud)), random_state=22)
df = df_normal.append(df_fraud)

df
# Out:
#                                              description  fraudulent
# 13898  Currently hiring per-diem caregivers to work o...           0
# 1688   Μεγαλώνουμε την ομάδα μας,και χρειαζόμαστε ένα...           0
# 13100  PowToon is looking for a team-oriented Marketi...           0
# 5579   Wealth Management Advisor We are continuing ou...           0
# 15961  RECRUITING MILITARY VETERANSLooking to offer o...           0
# ...                                                  ...         ...
# 17827  Student Positions Part-Time and Full-Time.You ...           1
# 17828  LEARN TO EARN AN EXECUTIVE LEVEL INCOMEFULL TR...           1
# 17829  inFullMobile Sp. z o.o. is a mobile software d...           1
# 17830  JOB DESCRIPTIONWe are seeking a full time payr...           1
# 17831  earn $500 to $1000 a week as a mover.  Must ha...           1
#
# [5056 rows x 2 columns]

# %%
# Shuffle the dataframe so fraudulent postings more evenly distributed 
from sklearn.utils import shuffle
df = shuffle(df, random_state=22)
df = df.reset_index(drop=True)
df
# Out:
#                                             description  fraudulent
# 0     Why is UX Design important for us?We want to b...           0
# 1     JOB DESCRIPTIONWe are seeking a full time payr...           1
# 2     Client Services Manager - SM1San Mateo, CA#URL...           1
# 3     Lead projects from beginning to end while fost...           0
# 4     Fast-growing E-commerce company has a fantasti...           0
# ...                                                 ...         ...
# 5051  Transifex is seeking a passionate UI/UX Develo...           0
# 5052           Normal  0          false  false  fals...           1
# 5053  CTO for a tourism start-upWe are just now star...           0
# 5054  OFFER Part Time Positions (Cash In Hand)You ca...           1
# 5055  Qubit: Cutting Edge Big Data EngineeringAt Qub...           0
#
# [5056 rows x 2 columns]

# %%
# Explicitly define data types
df['description'] = df['description'].astype(str)
df['fraudulent'] = df['fraudulent'].astype(int)

# %%
# Datatypes
df.dtypes
# Out:
# description    object
# fraudulent      int64
# dtype: object

# %%
# Count Real vs Fraudulent again to make sure we've achieved the desired result
print(Counter(df['fraudulent'].values))
# Out:
# Counter({0: 4424, 1: 632})

# %% [markdown]
# ## **Data Pre-Processing**

# %%
# Change all the text to lowercase
df['description'] = [x.lower() for x in df['description']]
df['description']
# Out:
# 0       why is ux design important for us?we want to b...
# 1       job descriptionwe are seeking a full time payr...
# 2       client services manager - sm1san mateo, ca#url...
# 3       lead projects from beginning to end while fost...
# 4       fast-growing e-commerce company has a fantasti...
#                               ...
# 5051    transifex is seeking a passionate ui/ux develo...
# 5052             normal  0          false  false  fals...
# 5053    cto for a tourism start-upwe are just now star...
# 5054    offer part time positions (cash in hand)you ca...
# 5055    qubit: cutting edge big data engineeringat qub...
# Name: description, Length: 5056, dtype: object

# %%
# Tokenization
df['description']= [word_tokenize(x) for x in df['description']]

# %%
# Remove Stop words and Non-Numeric. Perfom Word Stemming/Lemmenting.
# WordNetLemmatizer requires Pos tags to understand if the word is noun or verb or adjective etc. By default it is set to Noun
tag_map = defaultdict(lambda : wn.NOUN)
tag_map['J'] = wn.ADJ
tag_map['V'] = wn.VERB
tag_map['R'] = wn.ADV

for index,entry in enumerate(df['description']):
    # Declare an Empty List to store the words that follow the rules for this step
    Final_words = []

    # Initialize WordNetLemmatizer()
    word_Lemmatized = WordNetLemmatizer()

    # pos_tag function to provide the 'tag' i.e if the word is Noun(N), Verb(V), ADJ(J) or ADV(R) or something else.
    for word, tag in pos_tag(entry):
        # Below condition is to check for Stop words and consider only alphabets
        if word not in stopwords.words('english') and word.isalpha():
            word_Final = word_Lemmatized.lemmatize(word,tag_map[tag[0]])
            Final_words.append(word_Final)

    # The final processed set of words for each iteration will be stored in 'text_final'
    df.loc[index,'text_final'] = str(Final_words)

df
# Out:
#                                             description  ...                                         text_final
# 0     [why, is, ux, design, important, for, us, ?, w...  ...  ['ux', 'design', 'important', 'u', 'want', 're...
# 1     [job, descriptionwe, are, seeking, a, full, ti...  ...  ['job', 'descriptionwe', 'seek', 'full', 'time...
# 2     [client, services, manager, -, sm1san, mateo, ...  ...  ['client', 'service', 'manager', 'mateo', 'ca'...
# 3     [lead, projects, from, beginning, to, end, whi...  ...  ['lead', 'project', 'begin', 'end', 'foster', ...
# 4     [fast-growing, e-commerce, company, has, a, fa...  ...  ['company', 'fantastic', 'opportunity', 'talen...
# ...                                                 ...  ...                                                ...
# 5051  [transifex, is, seeking, a, passionate, ui/ux,...  ...  ['transifex', 'seek', 'passionate', 'developer...
# 5052  [normal, 0, false, false, false, en-us, x-none...  ...  ['normal', 'false', 'false', 'false', 'style',...
# 5053  [cto, for, a, tourism, start-upwe, are, just, ...  ...  ['cto', 'tourism', 'start', 'want', 'join', 'a...
# 5054  [offer, part, time, positions, (, cash, in, ha...  ...  ['offer', 'part', 'time', 'position', 'cash', ...
# 5055  [qubit, :, cutting, edge, big, data, engineeri...  ...  ['qubit', 'cutting', 'edge', 'big', 'data', 'e...
#
# [5056 rows x 3 columns]

# %%
# Reorganize Columns
df = df[['description','text_final','fraudulent']]
df
# Out:
#                                             description  ... fraudulent
# 0     [why, is, ux, design, important, for, us, ?, w...  ...          0
# 1     [job, descriptionwe, are, seeking, a, full, ti...  ...          1
# 2     [client, services, manager, -, sm1san, mateo, ...  ...          1
# 3     [lead, projects, from, beginning, to, end, whi...  ...          0
# 4     [fast-growing, e-commerce, company, has, a, fa...  ...          0
# ...                                                 ...  ...        ...
# 5051  [transifex, is, seeking, a, passionate, ui/ux,...  ...          0
# 5052  [normal, 0, false, false, false, en-us, x-none...  ...          1
# 5053  [cto, for, a, tourism, start-upwe, are, just, ...  ...          0
# 5054  [offer, part, time, positions, (, cash, in, ha...  ...          1
# 5055  [qubit, :, cutting, edge, big, data, engineeri...  ...          0
#
# [5056 rows x 3 columns]

# %% [markdown]
# ## **Prepare Training/Testing Data**

# %%
# Prepare Train and Test Data sets
X_train, X_test, Y_train, Y_test = model_selection.train_test_split(df['text_final'],df['fraudulent'],test_size=0.3)

# %% [markdown]
# ## **Word Vectorization w TF-IDF**

# %%
# Word Vectorization using method TF-IDF
Tfidf_vect = TfidfVectorizer(max_features=5000)
Tfidf_vect.fit(df['text_final'])
X_train_Tfidf = Tfidf_vect.transform(X_train)
X_test_Tfidf = Tfidf_vect.transform(X_test)

# View the vocab its learned
print(Tfidf_vect.vocabulary_)
print(X_train_Tfidf)
# Out:
# {'ux': 4739, 'design': 1225, 'important': 2201, 'want': 4844, 'reference': 3678, 'term': 4455, 'user': 4724, 'experience': 1645, 'within': 4917, 'financial': 1758, 'service': 4024, 'industry': 2250, 'aspect': 308, 'designer': 1228, 'shape': 4046, 'offer': 3012, 'customer': 1108, 'strive': 4300, 'everyday': 1597, 'make': 2658, 'great': 1982, 'possible': 3358, 'example': 1608, 'problem': 3452, 'work': 4926, 'develop': 1248, 'information': 2261, 'flow': 1803, 'new': 2932, 'optimize': 3067, 'touch': 4544, 'point': 3330, 'job': 2419, 'descriptionwe': 1223, 'seek': 3990, 'full': 1882, 'time': 4511, 'payroll': 3209, 'clerk': 770, 'manage': 2665, 'day': 1134, 'accounting': 37, 'operation': 3050, 'pay': 3203, 'scale': 3932, 'balancing': 430, 'company': 863, 'processing': 3461, 'weekly': 4870, 'credit': 1068, 'overall': 3122, 'record': 3657, 'keep': 2452, 'client': 773, 'manager': 2670, 'mateo': 2708, 'ca': 599, 'lead': 2520, 'way': 4857, 'technology': 4438, 'evolve': 1603, 'change': 700, 'medium': 2742, 'landscape': 2499, 'description': 1221, 'assign': 319, 'specific': 4197, 'account': 33, 'responsible': 3800, 'successful': 4332, 'execution': 1626, 'campaign': 620, 'run': 3883, 'platform': 3314, 'set': 4033, 'moderate': 2826, 'ensure': 1521, 'billing': 497, 'complete': 885, 'primary': 3431, 'owner': 3137, 'assigned': 320, 'agency': 131, 'publisher': 3540, 'well': 4875, 'director': 1289, 'sale': 3899, 'region': 3687, 'meet': 2744, 'exceed': 1609, 'expectation': 1641, 'may': 2721, 'coordinator': 1012, 'peer': 3216, 'handle': 2025, 'certain': 686, 'basis': 445, 'key': 2457, 'responsibility': 3799, 'include': 2218, 'maintaining': 2653, 'strong': 4301, 'communication': 856, 'stakeholder': 4240, 'inform': 2258, 'process': 3460, 'execute': 1625, 'every': 1596, 'case': 655, 'delegate': 1179, 'task': 4413, 'solve': 4154, 'common': 851, 'technical': 4432, 'address': 77, 'performance': 3231, 'objective': 2995, 'optimization': 3066, 'expand': 1638, 'relationship': 3709, 'notify': 2971, 'future': 1899, 'business': 592, 'maintain': 2651, 'expert': 1652, 'level': 2550, 'proficiency': 3475, 'tool': 4534, 'project': 3492, 'begin': 462, 'end': 1492, 'foster': 1846, 'directly': 1288, 'research': 3770, 'scope': 3949, 'development': 1253, 'creative': 1060, 'briefing': 563, 'contact': 967, 'management': 2667, 'status': 4256, 'meeting': 2745, 'organize': 3086, 'share': 4049, 'procedure': 3454, 'serve': 4022, 'implementers': 2196, 'achieve': 45, 'strategic': 4284, 'brand': 551, 'provide': 3527, 'guidance': 2007, 'internal': 2352, 'team': 4425, 'strategy': 4288, 'vital': 4818, 'role': 3859, 'promote': 3497, 'integration': 2328, 'seamless': 3970, 'delivery': 1189, 'candidate': 627, 'must': 2880, 'prepare': 3402, 'environment': 1539, 'comfortable': 835, 'opportunity': 3056, 'arise': 284, 'luxury': 2634, 'car': 638, 'vml': 4819, 'vary': 4764, 'ideal': 2162, 'ready': 3622, 'deliver': 1184, 'across': 52, 'wide': 4892, 'variety': 4762, 'area': 281, 'digital': 1277, 'able': 5, 'assist': 323, 'piece': 3288, 'delivers': 1188, 'defined': 1172, 'goal': 1961, 'fantastic': 1710, 'talented': 4404, 'qa': 3562, 'own': 3136, 'operate': 3048, 'internet': 2356, 'leading': 2523, 'site': 4105, 'military': 2795, 'police': 3333, 'fire': 1768, 'related': 3706, 'government': 1967, 'serf': 4017, 'major': 2656, 'sport': 4218, 'verification': 4780, 'also': 177, 'premium': 3397, 'product': 3467, 'tactical': 4399, 'use': 4722, 'exclusive': 1622, 'price': 3427, 'patent': 3196, 'pending': 3218, 'software': 4144, 'quickly': 3584, 'previously': 3426, 'found': 1847, 'engineer': 1503, 'critical': 1074, 'part': 3174, 'determine': 1245, 'appropriate': 260, 'functional': 1886, 'test': 4460, 'build': 584, 'play': 3315, 'help': 2061, 'high': 2076, 'quality': 3571, 'market': 2698, 'require': 3765, 'understanding': 4656, 'sql': 4226, 'query': 3578, 'writing': 4946, 'code': 803, 'position': 3349, 'skill': 4110, 'ability': 4, 'adapt': 66, 'duty': 1391, 'amp': 194, 'effort': 1439, 'detailed': 1239, 'corre ...
#   (0, 4825)	0.06665132145385252
#   (0, 4763)	0.10929202939631881
#   (0, 4762)	0.06341117706490496
#   (0, 4722)	0.07681191823452298
#   (0, 4668)	0.0616646294018557
#   (0, 4630)	0.0903664355909503
#   (0, 4564)	0.052688657502307015
#   (0, 4511)	0.041233186516663814
#   (0, 4425)	0.025118097169802095
#   (0, 4410)	0.06236407249482007
#   (0, 4356)	0.07023421381094128
#   (0, 4354)	0.23156914105627796
#   (0, 4236)	0.05278584657952858
#   (0, 4191)	0.06965635025688557
#   (0, 3941)	0.08088963408520894
#   (0, 3939)	0.055743467065495864
#   (0, 3895)	0.058428163833145544
#   (0, 3892)	0.14897210518439355
#   (0, 3882)	0.08408027601585792
#   (0, 3821)	0.05551006613961053
#   (0, 3799)	0.0818163615022663
#   (0, 3790)	0.07461497718739696
#   (0, 3784)	0.16746612071564912
#   (0, 3765)	0.08184701298493911
#   (0, 3753)	0.04257045589242621
#   :	:
#   (3538, 971)	0.044359720470390766
#   (3538, 912)	0.06368628737078669
#   (3538, 883)	0.06906409472842764
#   (3538, 863)	0.04851945988679023
#   (3538, 856)	0.06803253041903468
#   (3538, 845)	0.05487519542813039
#   (3538, 730)	0.06560192661339717
#   (3538, 715)	0.05426243986636363
#   (3538, 644)	0.04309544966616106
#   (3538, 642)	0.042682071164930176
#   (3538, 566)	0.04452733673229078
#   (3538, 340)	0.07038284564758984
#   (3538, 327)	0.04678151103705632
#   (3538, 325)	0.051708991294142144
#   (3538, 313)	0.07636641609560704
#   (3538, 291)	0.07944566061928503
#   (3538, 286)	0.04595782910084453
#   (3538, 260)	0.04529337101122196
#   (3538, 216)	0.08982722651014242
#   (3538, 184)	0.05882625550218092
#   (3538, 182)	0.05360784493112049
#   (3538, 177)	0.03437943814084794
#   (3538, 127)	0.07354191167612628
#   (3538, 110)	0.06523060857125382
#   (3538, 59)	0.05739516573929934

# %% [markdown]
# # **Train/ Evaluate Model**

# %%
# Classifier Algorithm= Support Vector Machine

# Fit the Classifier w the Training Data
SVM = svm.SVC(C=1.0, kernel='linear', degree=3, gamma='auto')
SVM.fit(X_train_Tfidf, Y_train)

# Use model to get predictions from the Testing data
predictions_SVM = SVM.predict(X_test_Tfidf)

# Use accuracy_score function to get the accuracy
print("SVM Accuracy Score: ", accuracy_score(predictions_SVM, Y_test)*100)
# Out:
# SVM Accuracy Score:  92.2874093605801

# %% [markdown]
# ## **Hypertune Model**

# %%
# Create the GridSearchCV model
from sklearn.model_selection import GridSearchCV
param_grid = {'C': [1, 5, 10, 100],
              'gamma': [0.001, 0.01, .1, 1],
              'kernel': ['linear','rbf', 'poly', 'sigmoid']}
grid = GridSearchCV(SVM, param_grid, verbose=3)

# %%
# Train the model with GridSearch
grid.fit(X_train_Tfidf, Y_train)
# Out:
# Fitting 5 folds for each of 64 candidates, totalling 320 fits
# [CV] C=1, gamma=0.001, kernel=linear .................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ..... C=1, gamma=0.001, kernel=linear, score=0.912, total=   3.0s
# [CV] C=1, gamma=0.001, kernel=linear .................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    3.0s remaining:    0.0s
# [CV] ..... C=1, gamma=0.001, kernel=linear, score=0.921, total=   2.9s
# [CV] C=1, gamma=0.001, kernel=linear .................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    5.9s remaining:    0.0s
# [CV] ..... C=1, gamma=0.001, kernel=linear, score=0.917, total=   3.0s
# [CV] C=1, gamma=0.001, kernel=linear .................................
# [CV] ..... C=1, gamma=0.001, kernel=linear, score=0.924, total=   3.0s
# [CV] C=1, gamma=0.001, kernel=linear .................................
# [CV] ..... C=1, gamma=0.001, kernel=linear, score=0.907, total=   3.0s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.876, total=   2.4s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.876, total=   2.4s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.874, total=   2.4s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.874, total=   2.3s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.876, total=   2.3s
# [CV] C=1, gamma=0.001, kernel=poly ...................................
# [CV] ....... C=1, gamma=0.001, kernel=poly, score=0.876, total=   2.0s
# [CV] C=1, gamma=0.001, kernel=poly ...................................
# [CV] ....... C=1, gamma=0.001, kernel=poly, score=0.876, total=   2.0s
# [CV] C=1, gamma=0.001, kernel=poly ...................................
# [CV] ....... C=1, gamma=0.001, kernel=poly, score=0.874, total=   2.0s
# [CV] C=1, gamma=0.001, kernel=poly ...................................
# [CV] ....... C=1, gamma=0.001, kernel=poly, score=0.874, total=   1.9s
# [CV] C=1, gamma=0.001, kernel=poly ...................................
# [CV] ....... C=1, gamma=0.001, kernel=poly, score=0.876, total=   2.0s
# [CV] C=1, gamma=0.001, kernel=sigmoid ................................
# [CV] .... C=1, gamma=0.001, kernel=sigmoid, score=0.876, total=   2.1s
# [CV] C=1, gamma=0.001, kernel=sigmoid ................................
# [CV] .... C=1, gamma=0.001, kernel=sigmoid, score=0.876, total=   2.1s
# [CV] C=1, gamma=0.001, kernel=sigmoid ................................
# [CV] .... C=1, gamma=0.001, kernel=sigmoid, score=0.874, total=   2.1s
# [CV] C=1, gamma=0.001, kernel=sigmoid ................................
# [CV] .... C=1, gamma=0.001, kernel=sigmoid, score=0.874, total=   2.1s
# [CV] C=1, gamma=0.001, kernel=sigmoid ................................
# [CV] .... C=1, gamma=0.001, kernel=sigmoid, score=0.876, total=   2.1s
# [CV] C=1, gamma=0.01, kernel=linear ..................................
# [CV] ...... C=1, gamma=0.01, kernel=linear, score=0.912, total=   3.0s
# [CV] C=1, gamma=0.01, kernel=linear ..................................
# [CV] ...... C=1, gamma=0.01, kernel=linear, score=0.921, total=   2.9s
# [CV] C=1, gamma=0.01, kernel=linear ..................................
# [CV] ...... C=1, gamma=0.01, kernel=linear, score=0.917, total=   3.0s
# [CV] C=1, gamma=0.01, kernel=linear ..................................
# [CV] ...... C=1, gamma=0.01, kernel=linear, score=0.924, total=   3.0s
# [CV] C=1, gamma=0.01, kernel=linear ..................................
# [CV] ...... C=1, gamma=0.01, kernel=linear, score=0.907, total=   3.0s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.876, total=   2.9s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.876, total=   2.9s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.874, total=   3.0s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.874, total=   2.9s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.876, total=   2.8s
# [CV] C=1, gamma=0.01, kernel=poly ....................................
# [CV] ........ C=1, gamma=0.01, kernel=poly, score=0.876, total=   2.0s
# [CV] C=1, gamma=0.01, kernel=poly ....................................
# [CV] ........ C=1, gamma=0.01, kernel=poly, score=0.876, total=   2.0s
# [CV] C=1, gamma=0.01, kernel=poly ....................................
# [CV] ........ C=1, gamma=0.01, kernel=poly, score=0.874, total=   1.9s
# [CV] C=1, gamma=0.01, kernel=poly ....................................
# [CV] ........ C=1, gamma=0.01, kernel=poly, score=0.874, total=   1.9s
# [CV] C=1, gamma=0.01, kernel=poly ....................................
# [CV] ........ C=1, gamma=0.01, kernel=poly, score=0.876, total=   2.0s
# [CV] C=1, gamma=0.01, kernel=sigmoid .................................
# [CV] ..... C=1, gamma=0.01, kernel=sigmoid, score=0.876, total=   2.8s
# [CV] C=1, gamma=0.01, kernel=sigmoid .................................
# [CV] ..... C=1, gamma=0.01, kernel=sigmoid, score=0.876, total=   2.8s
# [CV] C=1, gamma=0.01, kernel=sigmoid .................................
# [CV] ..... C=1, gamma=0.01, kernel=sigmoid, score=0.874, total=   2.9s
# [CV] C=1, gamma=0.01, kernel=sigmoid .................................
# [CV] ..... C=1, gamma=0.01, kernel=sigmoid, score=0.874, total=   2.9s
# [CV] C=1, gamma=0.01, kernel=sigmoid .................................
# [CV] ..... C=1, gamma=0.01, kernel=sigmoid, score=0.876, total=   2.8s
# [CV] C=1, gamma=0.1, kernel=linear ...................................
# [CV] ....... C=1, gamma=0.1, kernel=linear, score=0.912, total=   3.0s
# [CV] C=1, gamma=0.1, kernel=linear ...................................
# [CV] ....... C=1, gamma=0.1, kernel=linear, score=0.921, total=   2.9s
# [CV] C=1, gamma=0.1, kernel=linear ...................................
# [CV] ....... C=1, gamma=0.1, kernel=linear, score=0.917, total=   3.0s
# [CV] C=1, gamma=0.1, kernel=linear ...................................
# [CV] ....... C=1, gamma=0.1, kernel=linear, score=0.924, total=   3.0s
# [CV] C=1, gamma=0.1, kernel=linear ...................................
# [CV] ....... C=1, gamma=0.1, kernel=linear, score=0.907, total=   3.0s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.880, total=   3.1s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.881, total=   3.2s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.879, total=   3.2s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.881, total=   3.2s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.878, total=   3.1s
# [CV] C=1, gamma=0.1, kernel=poly .....................................
# [CV] ......... C=1, gamma=0.1, kernel=poly, score=0.876, total=   2.0s
# [CV] C=1, gamma=0.1, kernel=poly .....................................
# [CV] ......... C=1, gamma=0.1, kernel=poly, score=0.876, total=   2.0s
# [CV] C=1, gamma=0.1, kernel=poly .....................................
# [CV] ......... C=1, gamma=0.1, kernel=poly, score=0.874, total=   2.0s
# [CV] C=1, gamma=0.1, kernel=poly .....................................
# [CV] ......... C=1, gamma=0.1, kernel=poly, score=0.874, total=   2.0s
# [CV] C=1, gamma=0.1, kernel=poly .....................................
# [CV] ......... C=1, gamma=0.1, kernel=poly, score=0.876, total=   2.0s
# [CV] C=1, gamma=0.1, kernel=sigmoid ..................................
# [CV] ...... C=1, gamma=0.1, kernel=sigmoid, score=0.877, total=   3.0s
# [CV] C=1, gamma=0.1, kernel=sigmoid ..................................
# [CV] ...... C=1, gamma=0.1, kernel=sigmoid, score=0.876, total=   3.0s
# [CV] C=1, gamma=0.1, kernel=sigmoid ..................................
# [CV] ...... C=1, gamma=0.1, kernel=sigmoid, score=0.874, total=   3.0s
# [CV] C=1, gamma=0.1, kernel=sigmoid ..................................
# [CV] ...... C=1, gamma=0.1, kernel=sigmoid, score=0.874, total=   3.0s
# [CV] C=1, gamma=0.1, kernel=sigmoid ..................................
# [CV] ...... C=1, gamma=0.1, kernel=sigmoid, score=0.876, total=   2.9s
# [CV] C=1, gamma=1, kernel=linear .....................................
# [CV] ......... C=1, gamma=1, kernel=linear, score=0.912, total=   3.0s
# [CV] C=1, gamma=1, kernel=linear .....................................
# [CV] ......... C=1, gamma=1, kernel=linear, score=0.921, total=   2.9s
# [CV] C=1, gamma=1, kernel=linear .....................................
# [CV] ......... C=1, gamma=1, kernel=linear, score=0.917, total=   3.0s
# [CV] C=1, gamma=1, kernel=linear .....................................
# [CV] ......... C=1, gamma=1, kernel=linear, score=0.924, total=   3.0s
# [CV] C=1, gamma=1, kernel=linear .....................................
# [CV] ......... C=1, gamma=1, kernel=linear, score=0.907, total=   3.0s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.904, total=   6.5s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.915, total=   6.4s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.921, total=   6.5s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.905, total=   6.5s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.908, total=   6.3s
# [CV] C=1, gamma=1, kernel=poly .......................................
# [CV] ........... C=1, gamma=1, kernel=poly, score=0.900, total=   8.0s
# [CV] C=1, gamma=1, kernel=poly .......................................
# [CV] ........... C=1, gamma=1, kernel=poly, score=0.908, total=   8.0s
# [CV] C=1, gamma=1, kernel=poly .......................................
# [CV] ........... C=1, gamma=1, kernel=poly, score=0.914, total=   8.1s
# [CV] C=1, gamma=1, kernel=poly .......................................
# [CV] ........... C=1, gamma=1, kernel=poly, score=0.907, total=   7.9s
# [CV] C=1, gamma=1, kernel=poly .......................................
# [CV] ........... C=1, gamma=1, kernel=poly, score=0.894, total=   7.9s
# [CV] C=1, gamma=1, kernel=sigmoid ....................................
# [CV] ........ C=1, gamma=1, kernel=sigmoid, score=0.907, total=   2.7s
# [CV] C=1, gamma=1, kernel=sigmoid ....................................
# [CV] ........ C=1, gamma=1, kernel=sigmoid, score=0.912, total=   2.6s
# [CV] C=1, gamma=1, kernel=sigmoid ....................................
# [CV] ........ C=1, gamma=1, kernel=sigmoid, score=0.910, total=   2.7s
# [CV] C=1, gamma=1, kernel=sigmoid ....................................
# [CV] ........ C=1, gamma=1, kernel=sigmoid, score=0.914, total=   2.7s
# [CV] C=1, gamma=1, kernel=sigmoid ....................................
# [CV] ........ C=1, gamma=1, kernel=sigmoid, score=0.905, total=   2.7s
# [CV] C=5, gamma=0.001, kernel=linear .................................
# [CV] ..... C=5, gamma=0.001, kernel=linear, score=0.912, total=   3.0s
# [CV] C=5, gamma=0.001, kernel=linear .................................
# [CV] ..... C=5, gamma=0.001, kernel=linear, score=0.917, total=   3.0s
# [CV] C=5, gamma=0.001, kernel=linear .................................
# [CV] ..... C=5, gamma=0.001, kernel=linear, score=0.914, total=   3.0s
# [CV] C=5, gamma=0.001, kernel=linear .................................
# [CV] ..... C=5, gamma=0.001, kernel=linear, score=0.925, total=   3.1s
# [CV] C=5, gamma=0.001, kernel=linear .................................
# [CV] ..... C=5, gamma=0.001, kernel=linear, score=0.902, total=   3.0s
# [CV] C=5, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=5, gamma=0.001, kernel=rbf, score=0.876, total=   2.8s
# [CV] C=5, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=5, gamma=0.001, kernel=rbf, score=0.876, total=   2.8s
# [CV] C=5, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=5, gamma=0.001, kernel=rbf, score=0.874, total=   2.8s
# [CV] C=5, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=5, gamma=0.001, kernel=rbf, score=0.874, total=   2.9s
# [CV] C=5, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=5, gamma=0.001, kernel=rbf, score=0.876, total=   2.8s
# [CV] C=5, gamma=0.001, kernel=poly ...................................
# [CV] ....... C=5, gamma=0.001, kernel=poly, score=0.876, total=   2.0s
# [CV] C=5, gamma=0.001, kernel=poly ...................................
# [CV] ....... C=5, gamma=0.001, kernel=poly, score=0.876, total=   2.0s
# [CV] C=5, gamma=0.001, kernel=poly ...................................
# [CV] ....... C=5, gamma=0.001, kernel=poly, score=0.874, total=   2.0s
# [CV] C=5, gamma=0.001, kernel=poly ...................................
# [CV] ....... C=5, gamma=0.001, kernel=poly, score=0.874, total=   1.9s
# [CV] C=5, gamma=0.001, kernel=poly ...................................
# [CV] ....... C=5, gamma=0.001, kernel=poly, score=0.876, total=   2.0s
# [CV] C=5, gamma=0.001, kernel=sigmoid ................................
# [CV] .... C=5, gamma=0.001, kernel=sigmoid, score=0.876, total=   2.7s
# [CV] C=5, gamma=0.001, kernel=sigmoid ................................
# [CV] .... C=5, gamma=0.001, kernel=sigmoid, score=0.876, total=   2.7s
# [CV] C=5, gamma=0.001, kernel=sigmoid ................................
# [CV] .... C=5, gamma=0.001, kernel=sigmoid, score=0.874, total=   2.7s
# [CV] C=5, gamma=0.001, kernel=sigmoid ................................
# [CV] .... C=5, gamma=0.001, kernel=sigmoid, score=0.874, total=   2.7s
# [CV] C=5, gamma=0.001, kernel=sigmoid ................................
# [CV] .... C=5, gamma=0.001, kernel=sigmoid, score=0.876, total=   2.7s
# [CV] C=5, gamma=0.01, kernel=linear ..................................
# [CV] ...... C=5, gamma=0.01, kernel=linear, score=0.912, total=   3.0s
# [CV] C=5, gamma=0.01, kernel=linear ..................................
# [CV] ...... C=5, gamma=0.01, kernel=linear, score=0.917, total=   3.0s
# [CV] C=5, gamma=0.01, kernel=linear ..................................
# [CV] ...... C=5, gamma=0.01, kernel=linear, score=0.914, total=   3.0s
# [CV] C=5, gamma=0.01, kernel=linear ..................................
# [CV] ...... C=5, gamma=0.01, kernel=linear, score=0.925, total=   3.1s
# [CV] C=5, gamma=0.01, kernel=linear ..................................
# [CV] ...... C=5, gamma=0.01, kernel=linear, score=0.902, total=   3.0s
# [CV] C=5, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=5, gamma=0.01, kernel=rbf, score=0.876, total=   3.0s
# [CV] C=5, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=5, gamma=0.01, kernel=rbf, score=0.876, total=   3.0s
# [CV] C=5, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=5, gamma=0.01, kernel=rbf, score=0.874, total=   3.1s
# [CV] C=5, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=5, gamma=0.01, kernel=rbf, score=0.874, total=   3.1s
# [CV] C=5, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=5, gamma=0.01, kernel=rbf, score=0.876, total=   3.0s
# [CV] C=5, gamma=0.01, kernel=poly ....................................
# [CV] ........ C=5, gamma=0.01, kernel=poly, score=0.876, total=   2.0s
# [CV] C=5, gamma=0.01, kernel=poly ....................................
# [CV] ........ C=5, gamma=0.01, kernel=poly, score=0.876, total=   2.0s
# [CV] C=5, gamma=0.01, kernel=poly ....................................
# [CV] ........ C=5, gamma=0.01, kernel=poly, score=0.874, total=   2.0s
# [CV] C=5, gamma=0.01, kernel=poly ....................................
# [CV] ........ C=5, gamma=0.01, kernel=poly, score=0.874, total=   1.9s
# [CV] C=5, gamma=0.01, kernel=poly ....................................
# [CV] ........ C=5, gamma=0.01, kernel=poly, score=0.876, total=   2.0s
# [CV] C=5, gamma=0.01, kernel=sigmoid .................................
# [CV] ..... C=5, gamma=0.01, kernel=sigmoid, score=0.876, total=   3.0s
# [CV] C=5, gamma=0.01, kernel=sigmoid .................................
# [CV] ..... C=5, gamma=0.01, kernel=sigmoid, score=0.876, total=   3.0s
# [CV] C=5, gamma=0.01, kernel=sigmoid .................................
# [CV] ..... C=5, gamma=0.01, kernel=sigmoid, score=0.874, total=   3.0s
# [CV] C=5, gamma=0.01, kernel=sigmoid .................................
# [CV] ..... C=5, gamma=0.01, kernel=sigmoid, score=0.874, total=   3.0s
# [CV] C=5, gamma=0.01, kernel=sigmoid .................................
# [CV] ..... C=5, gamma=0.01, kernel=sigmoid, score=0.876, total=   2.9s
# [CV] C=5, gamma=0.1, kernel=linear ...................................
# [CV] ....... C=5, gamma=0.1, kernel=linear, score=0.912, total=   3.0s
# [CV] C=5, gamma=0.1, kernel=linear ...................................
# [CV] ....... C=5, gamma=0.1, kernel=linear, score=0.917, total=   3.0s
# [CV] C=5, gamma=0.1, kernel=linear ...................................
# [CV] ....... C=5, gamma=0.1, kernel=linear, score=0.914, total=   3.0s
# [CV] C=5, gamma=0.1, kernel=linear ...................................
# [CV] ....... C=5, gamma=0.1, kernel=linear, score=0.925, total=   3.1s
# [CV] C=5, gamma=0.1, kernel=linear ...................................
# [CV] ....... C=5, gamma=0.1, kernel=linear, score=0.902, total=   3.0s
# [CV] C=5, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=5, gamma=0.1, kernel=rbf, score=0.914, total=   3.3s
# [CV] C=5, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=5, gamma=0.1, kernel=rbf, score=0.917, total=   3.1s
# [CV] C=5, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=5, gamma=0.1, kernel=rbf, score=0.919, total=   3.2s
# [CV] C=5, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=5, gamma=0.1, kernel=rbf, score=0.918, total=   3.2s
# [CV] C=5, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=5, gamma=0.1, kernel=rbf, score=0.909, total=   3.2s
# [CV] C=5, gamma=0.1, kernel=poly .....................................
# [CV] ......... C=5, gamma=0.1, kernel=poly, score=0.876, total=   5.9s
# [CV] C=5, gamma=0.1, kernel=poly .....................................
# [CV] ......... C=5, gamma=0.1, kernel=poly, score=0.876, total=   5.8s
# [CV] C=5, gamma=0.1, kernel=poly .....................................
# [CV] ......... C=5, gamma=0.1, kernel=poly, score=0.874, total=   5.9s
# [CV] C=5, gamma=0.1, kernel=poly .....................................
# [CV] ......... C=5, gamma=0.1, kernel=poly, score=0.874, total=   5.9s
# [CV] C=5, gamma=0.1, kernel=poly .....................................
# [CV] ......... C=5, gamma=0.1, kernel=poly, score=0.876, total=   5.8s
# [CV] C=5, gamma=0.1, kernel=sigmoid ..................................
# [CV] ...... C=5, gamma=0.1, kernel=sigmoid, score=0.894, total=   3.1s
# [CV] C=5, gamma=0.1, kernel=sigmoid ..................................
# [CV] ...... C=5, gamma=0.1, kernel=sigmoid, score=0.898, total=   3.1s
# [CV] C=5, gamma=0.1, kernel=sigmoid ..................................
# [CV] ...... C=5, gamma=0.1, kernel=sigmoid, score=0.905, total=   3.1s
# [CV] C=5, gamma=0.1, kernel=sigmoid ..................................
# [CV] ...... C=5, gamma=0.1, kernel=sigmoid, score=0.895, total=   3.2s
# [CV] C=5, gamma=0.1, kernel=sigmoid ..................................
# [CV] ...... C=5, gamma=0.1, kernel=sigmoid, score=0.900, total=   3.0s
# [CV] C=5, gamma=1, kernel=linear .....................................
# [CV] ......... C=5, gamma=1, kernel=linear, score=0.912, total=   3.1s
# [CV] C=5, gamma=1, kernel=linear .....................................
# [CV] ......... C=5, gamma=1, kernel=linear, score=0.917, total=   3.0s
# [CV] C=5, gamma=1, kernel=linear .....................................
# [CV] ......... C=5, gamma=1, kernel=linear, score=0.914, total=   3.0s
# [CV] C=5, gamma=1, kernel=linear .....................................
# [CV] ......... C=5, gamma=1, kernel=linear, score=0.925, total=   3.1s
# [CV] C=5, gamma=1, kernel=linear .....................................
# [CV] ......... C=5, gamma=1, kernel=linear, score=0.902, total=   3.0s
# [CV] C=5, gamma=1, kernel=rbf ........................................
# [CV] ............ C=5, gamma=1, kernel=rbf, score=0.922, total=   7.0s
# [CV] C=5, gamma=1, kernel=rbf ........................................
# [CV] ............ C=5, gamma=1, kernel=rbf, score=0.932, total=   6.8s
# [CV] C=5, gamma=1, kernel=rbf ........................................
# [CV] ............ C=5, gamma=1, kernel=rbf, score=0.925, total=   7.1s
# [CV] C=5, gamma=1, kernel=rbf ........................................
# [CV] ............ C=5, gamma=1, kernel=rbf, score=0.924, total=   7.0s
# [CV] C=5, gamma=1, kernel=rbf ........................................
# [CV] ............ C=5, gamma=1, kernel=rbf, score=0.921, total=   6.8s
# [CV] C=5, gamma=1, kernel=poly .......................................
# [CV] ........... C=5, gamma=1, kernel=poly, score=0.905, total=   8.3s
# [CV] C=5, gamma=1, kernel=poly .......................................
# [CV] ........... C=5, gamma=1, kernel=poly, score=0.917, total=   8.3s
# [CV] C=5, gamma=1, kernel=poly .......................................
# [CV] ........... C=5, gamma=1, kernel=poly, score=0.917, total=   8.2s
# [CV] C=5, gamma=1, kernel=poly .......................................
# [CV] ........... C=5, gamma=1, kernel=poly, score=0.915, total=   8.4s
# [CV] C=5, gamma=1, kernel=poly .......................................
# [CV] ........... C=5, gamma=1, kernel=poly, score=0.908, total=   8.2s
# [CV] C=5, gamma=1, kernel=sigmoid ....................................
# [CV] ........ C=5, gamma=1, kernel=sigmoid, score=0.908, total=   2.6s
# [CV] C=5, gamma=1, kernel=sigmoid ....................................
# [CV] ........ C=5, gamma=1, kernel=sigmoid, score=0.910, total=   2.5s
# [CV] C=5, gamma=1, kernel=sigmoid ....................................
# [CV] ........ C=5, gamma=1, kernel=sigmoid, score=0.911, total=   2.5s
# [CV] C=5, gamma=1, kernel=sigmoid ....................................
# [CV] ........ C=5, gamma=1, kernel=sigmoid, score=0.919, total=   2.5s
# [CV] C=5, gamma=1, kernel=sigmoid ....................................
# [CV] ........ C=5, gamma=1, kernel=sigmoid, score=0.890, total=   2.5s
# [CV] C=10, gamma=0.001, kernel=linear ................................
# [CV] .... C=10, gamma=0.001, kernel=linear, score=0.910, total=   3.1s
# [CV] C=10, gamma=0.001, kernel=linear ................................
# [CV] .... C=10, gamma=0.001, kernel=linear, score=0.915, total=   3.0s
# [CV] C=10, gamma=0.001, kernel=linear ................................
# [CV] .... C=10, gamma=0.001, kernel=linear, score=0.918, total=   3.1s
# [CV] C=10, gamma=0.001, kernel=linear ................................
# [CV] .... C=10, gamma=0.001, kernel=linear, score=0.927, total=   3.1s
# [CV] C=10, gamma=0.001, kernel=linear ................................
# [CV] .... C=10, gamma=0.001, kernel=linear, score=0.897, total=   2.9s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.876, total=   3.0s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.876, total=   2.9s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.874, total=   3.0s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.874, total=   3.0s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.876, total=   2.9s
# [CV] C=10, gamma=0.001, kernel=poly ..................................
# [CV] ...... C=10, gamma=0.001, kernel=poly, score=0.876, total=   2.0s
# [CV] C=10, gamma=0.001, kernel=poly ..................................
# [CV] ...... C=10, gamma=0.001, kernel=poly, score=0.876, total=   2.0s
# [CV] C=10, gamma=0.001, kernel=poly ..................................
# [CV] ...... C=10, gamma=0.001, kernel=poly, score=0.874, total=   2.0s
# [CV] C=10, gamma=0.001, kernel=poly ..................................
# [CV] ...... C=10, gamma=0.001, kernel=poly, score=0.874, total=   2.0s
# [CV] C=10, gamma=0.001, kernel=poly ..................................
# [CV] ...... C=10, gamma=0.001, kernel=poly, score=0.876, total=   2.0s
# [CV] C=10, gamma=0.001, kernel=sigmoid ...............................
# [CV] ... C=10, gamma=0.001, kernel=sigmoid, score=0.876, total=   2.8s
# [CV] C=10, gamma=0.001, kernel=sigmoid ...............................
# [CV] ... C=10, gamma=0.001, kernel=sigmoid, score=0.876, total=   2.8s
# [CV] C=10, gamma=0.001, kernel=sigmoid ...............................
# [CV] ... C=10, gamma=0.001, kernel=sigmoid, score=0.874, total=   2.9s
# [CV] C=10, gamma=0.001, kernel=sigmoid ...............................
# [CV] ... C=10, gamma=0.001, kernel=sigmoid, score=0.874, total=   2.9s
# [CV] C=10, gamma=0.001, kernel=sigmoid ...............................
# [CV] ... C=10, gamma=0.001, kernel=sigmoid, score=0.876, total=   2.8s
# [CV] C=10, gamma=0.01, kernel=linear .................................
# [CV] ..... C=10, gamma=0.01, kernel=linear, score=0.910, total=   3.1s
# [CV] C=10, gamma=0.01, kernel=linear .................................
# [CV] ..... C=10, gamma=0.01, kernel=linear, score=0.915, total=   3.0s
# [CV] C=10, gamma=0.01, kernel=linear .................................
# [CV] ..... C=10, gamma=0.01, kernel=linear, score=0.918, total=   3.1s
# [CV] C=10, gamma=0.01, kernel=linear .................................
# [CV] ..... C=10, gamma=0.01, kernel=linear, score=0.927, total=   3.1s
# [CV] C=10, gamma=0.01, kernel=linear .................................
# [CV] ..... C=10, gamma=0.01, kernel=linear, score=0.897, total=   3.0s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.880, total=   3.1s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.884, total=   3.1s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.880, total=   3.1s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.881, total=   3.1s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.878, total=   3.1s
# [CV] C=10, gamma=0.01, kernel=poly ...................................
# [CV] ....... C=10, gamma=0.01, kernel=poly, score=0.876, total=   2.0s
# [CV] C=10, gamma=0.01, kernel=poly ...................................
# [CV] ....... C=10, gamma=0.01, kernel=poly, score=0.876, total=   2.0s
# [CV] C=10, gamma=0.01, kernel=poly ...................................
# [CV] ....... C=10, gamma=0.01, kernel=poly, score=0.874, total=   2.0s
# [CV] C=10, gamma=0.01, kernel=poly ...................................
# [CV] ....... C=10, gamma=0.01, kernel=poly, score=0.874, total=   2.0s
# [CV] C=10, gamma=0.01, kernel=poly ...................................
# [CV] ....... C=10, gamma=0.01, kernel=poly, score=0.876, total=   2.0s
# [CV] C=10, gamma=0.01, kernel=sigmoid ................................
# [CV] .... C=10, gamma=0.01, kernel=sigmoid, score=0.877, total=   3.0s
# [CV] C=10, gamma=0.01, kernel=sigmoid ................................
# [CV] .... C=10, gamma=0.01, kernel=sigmoid, score=0.876, total=   3.0s
# [CV] C=10, gamma=0.01, kernel=sigmoid ................................
# [CV] .... C=10, gamma=0.01, kernel=sigmoid, score=0.874, total=   3.1s
# [CV] C=10, gamma=0.01, kernel=sigmoid ................................
# [CV] .... C=10, gamma=0.01, kernel=sigmoid, score=0.874, total=   3.1s
# [CV] C=10, gamma=0.01, kernel=sigmoid ................................
# [CV] .... C=10, gamma=0.01, kernel=sigmoid, score=0.876, total=   3.0s
# [CV] C=10, gamma=0.1, kernel=linear ..................................
# [CV] ...... C=10, gamma=0.1, kernel=linear, score=0.910, total=   3.1s
# [CV] C=10, gamma=0.1, kernel=linear ..................................
# [CV] ...... C=10, gamma=0.1, kernel=linear, score=0.915, total=   3.0s
# [CV] C=10, gamma=0.1, kernel=linear ..................................
# [CV] ...... C=10, gamma=0.1, kernel=linear, score=0.918, total=   3.1s
# [CV] C=10, gamma=0.1, kernel=linear ..................................
# [CV] ...... C=10, gamma=0.1, kernel=linear, score=0.927, total=   3.1s
# [CV] C=10, gamma=0.1, kernel=linear ..................................
# [CV] ...... C=10, gamma=0.1, kernel=linear, score=0.897, total=   3.0s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.915, total=   3.4s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.924, total=   3.2s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.925, total=   3.3s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.928, total=   3.4s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.908, total=   3.3s
# [CV] C=10, gamma=0.1, kernel=poly ....................................
# [CV] ........ C=10, gamma=0.1, kernel=poly, score=0.876, total=   7.4s
# [CV] C=10, gamma=0.1, kernel=poly ....................................
# [CV] ........ C=10, gamma=0.1, kernel=poly, score=0.876, total=   7.3s
# [CV] C=10, gamma=0.1, kernel=poly ....................................
# [CV] ........ C=10, gamma=0.1, kernel=poly, score=0.874, total=   7.4s
# [CV] C=10, gamma=0.1, kernel=poly ....................................
# [CV] ........ C=10, gamma=0.1, kernel=poly, score=0.874, total=   7.5s
# [CV] C=10, gamma=0.1, kernel=poly ....................................
# [CV] ........ C=10, gamma=0.1, kernel=poly, score=0.876, total=   7.4s
# [CV] C=10, gamma=0.1, kernel=sigmoid .................................
# [CV] ..... C=10, gamma=0.1, kernel=sigmoid, score=0.912, total=   3.2s
# [CV] C=10, gamma=0.1, kernel=sigmoid .................................
# [CV] ..... C=10, gamma=0.1, kernel=sigmoid, score=0.921, total=   3.1s
# [CV] C=10, gamma=0.1, kernel=sigmoid .................................
# [CV] ..... C=10, gamma=0.1, kernel=sigmoid, score=0.917, total=   3.1s
# [CV] C=10, gamma=0.1, kernel=sigmoid .................................
# [CV] ..... C=10, gamma=0.1, kernel=sigmoid, score=0.922, total=   3.1s
# [CV] C=10, gamma=0.1, kernel=sigmoid .................................
# [CV] ..... C=10, gamma=0.1, kernel=sigmoid, score=0.907, total=   3.1s
# [CV] C=10, gamma=1, kernel=linear ....................................
# [CV] ........ C=10, gamma=1, kernel=linear, score=0.910, total=   3.1s
# [CV] C=10, gamma=1, kernel=linear ....................................
# [CV] ........ C=10, gamma=1, kernel=linear, score=0.915, total=   3.0s
# [CV] C=10, gamma=1, kernel=linear ....................................
# [CV] ........ C=10, gamma=1, kernel=linear, score=0.918, total=   3.1s
# [CV] C=10, gamma=1, kernel=linear ....................................
# [CV] ........ C=10, gamma=1, kernel=linear, score=0.927, total=   3.1s
# [CV] C=10, gamma=1, kernel=linear ....................................
# [CV] ........ C=10, gamma=1, kernel=linear, score=0.897, total=   2.9s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.922, total=   7.1s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.932, total=   6.9s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.924, total=   7.2s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.924, total=   7.2s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.919, total=   6.9s
# [CV] C=10, gamma=1, kernel=poly ......................................
# [CV] .......... C=10, gamma=1, kernel=poly, score=0.905, total=   8.5s
# [CV] C=10, gamma=1, kernel=poly ......................................
# [CV] .......... C=10, gamma=1, kernel=poly, score=0.917, total=   8.5s
# [CV] C=10, gamma=1, kernel=poly ......................................
# [CV] .......... C=10, gamma=1, kernel=poly, score=0.917, total=   8.3s
# [CV] C=10, gamma=1, kernel=poly ......................................
# [CV] .......... C=10, gamma=1, kernel=poly, score=0.915, total=   8.3s
# [CV] C=10, gamma=1, kernel=poly ......................................
# [CV] .......... C=10, gamma=1, kernel=poly, score=0.908, total=   8.6s
# [CV] C=10, gamma=1, kernel=sigmoid ...................................
# [CV] ....... C=10, gamma=1, kernel=sigmoid, score=0.900, total=   2.8s
# [CV] C=10, gamma=1, kernel=sigmoid ...................................
# [CV] ....... C=10, gamma=1, kernel=sigmoid, score=0.903, total=   2.5s
# [CV] C=10, gamma=1, kernel=sigmoid ...................................
# [CV] ....... C=10, gamma=1, kernel=sigmoid, score=0.887, total=   2.3s
# [CV] C=10, gamma=1, kernel=sigmoid ...................................
# [CV] ....... C=10, gamma=1, kernel=sigmoid, score=0.917, total=   2.5s
# [CV] C=10, gamma=1, kernel=sigmoid ...................................
# [CV] ....... C=10, gamma=1, kernel=sigmoid, score=0.870, total=   2.4s
# [CV] C=100, gamma=0.001, kernel=linear ...............................
# [CV] ... C=100, gamma=0.001, kernel=linear, score=0.907, total=   3.1s
# [CV] C=100, gamma=0.001, kernel=linear ...............................
# [CV] ... C=100, gamma=0.001, kernel=linear, score=0.917, total=   3.0s
# [CV] C=100, gamma=0.001, kernel=linear ...............................
# [CV] ... C=100, gamma=0.001, kernel=linear, score=0.912, total=   3.1s
# [CV] C=100, gamma=0.001, kernel=linear ...............................
# [CV] ... C=100, gamma=0.001, kernel=linear, score=0.915, total=   3.1s
# [CV] C=100, gamma=0.001, kernel=linear ...............................
# [CV] ... C=100, gamma=0.001, kernel=linear, score=0.897, total=   2.9s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.880, total=   3.1s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.884, total=   3.1s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.880, total=   3.2s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.881, total=   3.1s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.878, total=   3.0s
# [CV] C=100, gamma=0.001, kernel=poly .................................
# [CV] ..... C=100, gamma=0.001, kernel=poly, score=0.876, total=   2.0s
# [CV] C=100, gamma=0.001, kernel=poly .................................
# [CV] ..... C=100, gamma=0.001, kernel=poly, score=0.876, total=   2.0s
# [CV] C=100, gamma=0.001, kernel=poly .................................
# [CV] ..... C=100, gamma=0.001, kernel=poly, score=0.874, total=   2.0s
# [CV] C=100, gamma=0.001, kernel=poly .................................
# [CV] ..... C=100, gamma=0.001, kernel=poly, score=0.874, total=   2.0s
# [CV] C=100, gamma=0.001, kernel=poly .................................
# [CV] ..... C=100, gamma=0.001, kernel=poly, score=0.876, total=   2.0s
# [CV] C=100, gamma=0.001, kernel=sigmoid ..............................
# [CV] .. C=100, gamma=0.001, kernel=sigmoid, score=0.877, total=   3.0s
# [CV] C=100, gamma=0.001, kernel=sigmoid ..............................
# [CV] .. C=100, gamma=0.001, kernel=sigmoid, score=0.876, total=   3.0s
# [CV] C=100, gamma=0.001, kernel=sigmoid ..............................
# [CV] .. C=100, gamma=0.001, kernel=sigmoid, score=0.874, total=   3.0s
# [CV] C=100, gamma=0.001, kernel=sigmoid ..............................
# [CV] .. C=100, gamma=0.001, kernel=sigmoid, score=0.874, total=   3.1s
# [CV] C=100, gamma=0.001, kernel=sigmoid ..............................
# [CV] .. C=100, gamma=0.001, kernel=sigmoid, score=0.876, total=   3.0s
# [CV] C=100, gamma=0.01, kernel=linear ................................
# [CV] .... C=100, gamma=0.01, kernel=linear, score=0.907, total=   3.0s
# [CV] C=100, gamma=0.01, kernel=linear ................................
# [CV] .... C=100, gamma=0.01, kernel=linear, score=0.917, total=   2.9s
# [CV] C=100, gamma=0.01, kernel=linear ................................
# [CV] .... C=100, gamma=0.01, kernel=linear, score=0.912, total=   3.1s
# [CV] C=100, gamma=0.01, kernel=linear ................................
# [CV] .... C=100, gamma=0.01, kernel=linear, score=0.915, total=   3.0s
# [CV] C=100, gamma=0.01, kernel=linear ................................
# [CV] .... C=100, gamma=0.01, kernel=linear, score=0.897, total=   2.9s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.921, total=   3.2s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.919, total=   3.1s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.919, total=   3.2s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.929, total=   3.2s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.905, total=   3.1s
# [CV] C=100, gamma=0.01, kernel=poly ..................................
# [CV] ...... C=100, gamma=0.01, kernel=poly, score=0.876, total=   2.0s
# [CV] C=100, gamma=0.01, kernel=poly ..................................
# [CV] ...... C=100, gamma=0.01, kernel=poly, score=0.876, total=   2.0s
# [CV] C=100, gamma=0.01, kernel=poly ..................................
# [CV] ...... C=100, gamma=0.01, kernel=poly, score=0.874, total=   2.0s
# [CV] C=100, gamma=0.01, kernel=poly ..................................
# [CV] ...... C=100, gamma=0.01, kernel=poly, score=0.874, total=   2.0s
# [CV] C=100, gamma=0.01, kernel=poly ..................................
# [CV] ...... C=100, gamma=0.01, kernel=poly, score=0.876, total=   2.0s
# [CV] C=100, gamma=0.01, kernel=sigmoid ...............................
# [CV] ... C=100, gamma=0.01, kernel=sigmoid, score=0.912, total=   3.1s
# [CV] C=100, gamma=0.01, kernel=sigmoid ...............................
# [CV] ... C=100, gamma=0.01, kernel=sigmoid, score=0.921, total=   3.0s
# [CV] C=100, gamma=0.01, kernel=sigmoid ...............................
# [CV] ... C=100, gamma=0.01, kernel=sigmoid, score=0.917, total=   3.1s
# [CV] C=100, gamma=0.01, kernel=sigmoid ...............................
# [CV] ... C=100, gamma=0.01, kernel=sigmoid, score=0.924, total=   3.1s
# [CV] C=100, gamma=0.01, kernel=sigmoid ...............................
# [CV] ... C=100, gamma=0.01, kernel=sigmoid, score=0.907, total=   3.1s
# [CV] C=100, gamma=0.1, kernel=linear .................................
# [CV] ..... C=100, gamma=0.1, kernel=linear, score=0.907, total=   3.0s
# [CV] C=100, gamma=0.1, kernel=linear .................................
# [CV] ..... C=100, gamma=0.1, kernel=linear, score=0.917, total=   2.9s
# [CV] C=100, gamma=0.1, kernel=linear .................................
# [CV] ..... C=100, gamma=0.1, kernel=linear, score=0.912, total=   3.1s
# [CV] C=100, gamma=0.1, kernel=linear .................................
# [CV] ..... C=100, gamma=0.1, kernel=linear, score=0.915, total=   3.0s
# [CV] C=100, gamma=0.1, kernel=linear .................................
# [CV] ..... C=100, gamma=0.1, kernel=linear, score=0.897, total=   2.8s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.914, total=   3.4s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.924, total=   3.3s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.918, total=   3.5s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.927, total=   3.5s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.911, total=   3.3s
# [CV] C=100, gamma=0.1, kernel=poly ...................................
# [CV] ....... C=100, gamma=0.1, kernel=poly, score=0.876, total=   7.9s
# [CV] C=100, gamma=0.1, kernel=poly ...................................
# [CV] ....... C=100, gamma=0.1, kernel=poly, score=0.876, total=   7.8s
# [CV] C=100, gamma=0.1, kernel=poly ...................................
# [CV] ....... C=100, gamma=0.1, kernel=poly, score=0.874, total=   7.8s
# [CV] C=100, gamma=0.1, kernel=poly ...................................
# [CV] ....... C=100, gamma=0.1, kernel=poly, score=0.874, total=   7.7s
# [CV] C=100, gamma=0.1, kernel=poly ...................................
# [CV] ....... C=100, gamma=0.1, kernel=poly, score=0.876, total=   7.7s
# [CV] C=100, gamma=0.1, kernel=sigmoid ................................
# [CV] .... C=100, gamma=0.1, kernel=sigmoid, score=0.910, total=   3.2s
# [CV] C=100, gamma=0.1, kernel=sigmoid ................................
# [CV] .... C=100, gamma=0.1, kernel=sigmoid, score=0.915, total=   3.0s
# [CV] C=100, gamma=0.1, kernel=sigmoid ................................
# [CV] .... C=100, gamma=0.1, kernel=sigmoid, score=0.917, total=   3.1s
# [CV] C=100, gamma=0.1, kernel=sigmoid ................................
# [CV] .... C=100, gamma=0.1, kernel=sigmoid, score=0.927, total=   3.0s
# [CV] C=100, gamma=0.1, kernel=sigmoid ................................
# [CV] .... C=100, gamma=0.1, kernel=sigmoid, score=0.897, total=   3.0s
# [CV] C=100, gamma=1, kernel=linear ...................................
# [CV] ....... C=100, gamma=1, kernel=linear, score=0.907, total=   3.0s
# [CV] C=100, gamma=1, kernel=linear ...................................
# [CV] ....... C=100, gamma=1, kernel=linear, score=0.917, total=   2.9s
# [CV] C=100, gamma=1, kernel=linear ...................................
# [CV] ....... C=100, gamma=1, kernel=linear, score=0.912, total=   3.1s
# [CV] C=100, gamma=1, kernel=linear ...................................
# [CV] ....... C=100, gamma=1, kernel=linear, score=0.915, total=   3.0s
# [CV] C=100, gamma=1, kernel=linear ...................................
# [CV] ....... C=100, gamma=1, kernel=linear, score=0.897, total=   2.8s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.924, total=   7.0s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.932, total=   6.8s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.925, total=   7.0s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.924, total=   7.0s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.921, total=   6.8s
# [CV] C=100, gamma=1, kernel=poly .....................................
# [CV] ......... C=100, gamma=1, kernel=poly, score=0.908, total=   8.5s
# [CV] C=100, gamma=1, kernel=poly .....................................
# [CV] ......... C=100, gamma=1, kernel=poly, score=0.917, total=   8.4s
# [CV] C=100, gamma=1, kernel=poly .....................................
# [CV] ......... C=100, gamma=1, kernel=poly, score=0.918, total=   8.5s
# [CV] C=100, gamma=1, kernel=poly .....................................
# [CV] ......... C=100, gamma=1, kernel=poly, score=0.915, total=   8.3s
# [CV] C=100, gamma=1, kernel=poly .....................................
# [CV] ......... C=100, gamma=1, kernel=poly, score=0.908, total=   8.2s
# [CV] C=100, gamma=1, kernel=sigmoid ..................................
# [CV] ...... C=100, gamma=1, kernel=sigmoid, score=0.836, total=   2.9s
# [CV] C=100, gamma=1, kernel=sigmoid ..................................
# [CV] ...... C=100, gamma=1, kernel=sigmoid, score=0.880, total=   3.2s
# [CV] C=100, gamma=1, kernel=sigmoid ..................................
# [CV] ...... C=100, gamma=1, kernel=sigmoid, score=0.856, total=   2.7s
# [CV] C=100, gamma=1, kernel=sigmoid ..................................
# [CV] ...... C=100, gamma=1, kernel=sigmoid, score=0.864, total=   2.9s
# [CV] C=100, gamma=1, kernel=sigmoid ..................................
# [CV] ...... C=100, gamma=1, kernel=sigmoid, score=0.846, total=   2.1s
# [Parallel(n_jobs=1)]: Done 320 out of 320 | elapsed: 19.1min finished
# GridSearchCV(cv=None, error_score=nan,
#              estimator=SVC(C=1.0, break_ties=False, cache_size=200,
#                            class_weight=None, coef0=0.0,
#                            decision_function_shape='ovr', degree=3,
#                            gamma='auto', kernel='linear', max_iter=-1,
#                            probability=False, random_state=None, shrinking=True,
#                            tol=0.001, verbose=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'C': [1, 5, 10, 100], 'gamma': [0.001, 0.01, 0.1, 1],
#                          'kernel': ['linear', 'rbf', 'poly', 'sigmoid']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'C': 100, 'gamma': 1, 'kernel': 'rbf'}
# 0.9251188678189852

# %%
# Train the hypertuned model
SVM2 = svm.SVC(kernel='rbf', C= 100, gamma= 1)
SVM2.fit(X_train_Tfidf, Y_train)
# Out:
# SVC(C=100, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=1, kernel='rbf', max_iter=-1,
#     probability=False, random_state=None, shrinking=True, tol=0.001,
#     verbose=False)

# %%
# Hypertuned Model Accuracy
print('SVM2 Acc Score: %.3f' % SVM2.score(X_test_Tfidf, Y_test))
# Out:
# SVM2 Acc Score: 0.930

# %%
from sklearn.metrics import classification_report
predictions = SVM2.predict(X_test_Tfidf)
print("SVM2 Classification Report: \n" + classification_report(Y_test, predictions, target_names=['real','fake']))
# Out:
# SVM2 Classification Report:
#               precision    recall  f1-score   support
#
#         real       0.93      1.00      0.96      1327
#         fake       0.94      0.47      0.63       190
#
#     accuracy                           0.93      1517
#    macro avg       0.93      0.73      0.80      1517
# weighted avg       0.93      0.93      0.92      1517

# %% [markdown]
# ## **Save Model**
